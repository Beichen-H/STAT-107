# %% [markdown]
# # Welcome to Lab: Similarity 🧍🧍‍♂️🧍‍♀️
#
# Many of you already know your tablemates in this class. However, have you ever wondered if there is someone **even more similar** to you than the people you already know?
#
# In this lab, we'll once again explore the dataset from the **Hello Survey** you've completed, utilizing some new Python skills to calculate your similarity to your peers!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "KUNLUN"
ca1_name = "JAI"
ca2_name = "Jessica"
ca3_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: What's your favorite (or least favorite) building on campus? 
partner1_name = "Christ Goncalves"
partner1_netid = "christg2"
partner1_favbuilding = "Union"

partner2_name = "Beichen Hu"
partner2_netid = "beichen7"
partner2_favbuilding = "Main library"

partner3_name = ""
partner3_netid = ""
partner3_favbuilding = ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello, Again

# %% [markdown]
# ## Load the Hello Dataset
# To find those most similar to you in this course, we're going to need the good old Hello Dataset.
#
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa24.csv
# ```
#
# Use Python to load this dataset into a DataFrame `df`:

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa24.csv")
df
# Out:
#            Name            Lab When flipping a coin, heads or tails?  \
# 0      Angelina            Y13                                 Tails
# 1      TA Tyler  Y07, Y10, Y20                                 Tails
# 2        Sneha             Y17                                 Tails
# 3          Gage            Y10                                 Heads
# 4         Mark             Y04                                 Heads
# ...         ...            ...                                   ...
# 1089  RuohanLiu            Y25                                 Tails
# 1090     Morgan            Y03                                 Heads
# 1091     Auggie            Y08                                 Heads
# 1092     Rebeca            Y10                                 Tails
# 1093      Tyler            Y26                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                  First Year at UIUC
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                  First Year at UIUC
# 4                      Not First Year
# ...                               ...
# 1089                   Not First Year
# 1090                   Not First Year
# 1091                   Not First Year
# 1092                   Not First Year
# 1093               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                               Vanilla
# 1                                             Chocolate
# 2                                               Vanilla
# 3                                               Vanilla
# 4                                             Chocolate
# ...                                                 ...
# 1089                                          Chocolate
# 1090                                            Vanilla
# 1091                                          Chocolate
# 1092                                          Chocolate
# 1093                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                           Morning                               Even
# 1                             Night                               Even
# 2                             Night                               Even
# 3                             Night                               Even
# 4                           Morning                               Even
# ...                             ...                                ...
# 1089                          Night                                Odd
# 1090                          Night                                Odd
# 1091                          Night                                Odd
# 1092                        Morning                               Even
# 1093                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                   Yes                          Summer
# 1                    No                          Winter
# 2                    No                          Summer
# 3                   Yes                          Winter
# 4                    No                          Winter
# ...                 ...                             ...
# 1089                Yes                          Winter
# 1090                 No                          Summer
# 1091                Yes                          Summer
# 1092                Yes                          Summer
# 1093                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                          Yes  ...
# 3                           No  ...
# 4                           No  ...
# ...                        ...  ...
# 1089                        No  ...
# 1090                        No  ...
# 1091                        No  ...
# 1092                        No  ...
# 1093                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                            Hong Kong
# 1                                                Canada
# 2                                                Canada
# 3                                               Canada
# 4                                                Sweden
# ...                                                 ...
# 1089                                              Chian
# 1090                                            England
# 1091                                             Canada
# 1092                                         Costa Rica
# 1093                                              China
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            Pink                        Watching shows
# 1                          Orange                              Terraria
# 2                           Green                 Reading or crocheting
# 3                           Green                   Fishing or Hunting
# 4                           green                               reading
# ...                           ...                                   ...
# 1089                         blue                                travel
# 1090                         Blue      Listening to music while drawing
# 1091                         blue                  hangout with friends
# 1092                          Red              Reading or playing music
# 1093                         Blue                           video games
#
#      What genre of music do you like the most?  \
# 0                                          r&b
# 1                                     Pop rock
# 2                                     Pop Rock
# 3                                 Grunge Rock
# 4                                          pop
# ...                                        ...
# 1089                                       pop
# 1090                                      LoFi
# 1091                                   Country
# 1092                        Indie folk and EDM
# 1093                                     Metal
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 Tiger
# 1                                                   Bee
# 2                                               Penguin
# 3                                                 Bear
# 4                                                 Zebra
# ...                                                 ...
# 1089                                                cat
# 1090                                           An Eagle
# 1091                                                Dog
# 1092                                                Dog
# 1093                                             jaguar
#
#      What do you think is the hardest major at UIUC?  \
# 0                             Aerospace engineering
# 1                               Chemical Engineering
# 2                                   Computer Science
# 3                                              Math
# 4                               computer engineering
# ...                                              ...
# 1089                                            math
# 1090                                             ECE
# 1091                               Actuarial Science
# 1092                 Engineering or computer science
# 1093                                              CS
#
#      Who is your favorite music artist?  \
# 0                         Ashley Alisha
# 1                            Billy Joel
# 2                       Imagine Dragons
# 3                            Jim Croce
# 4                                   sza
# ...                                 ...
# 1089                       Talyor swift
# 1090                       Smyang Piano
# 1091                         Zach Bryan
# 1092                   Cosmos Sheldrake
# 1093            Bullet for My Valentine
#
#      What's your favorite social media app?  \
# 0                                     Insta
# 1                                    Reddit
# 2                                 Instagram
# 3                                    Tiktok
# 4                                 instagram
# ...                                     ...
# 1089                                    ins
# 1090                              Instagram
# 1091                                tik tok
# 1092                               Pintrest
# 1093                               Bilibili
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                                   NaN
# 1                                              Terraria
# 2                                            Beat Saber
# 3                                           Titanfall 2
# 4                                              Fortnite
# ...                                                 ...
# 1089                                              PUBG
# 1090                                         Overcooked
# 1091                                         Card games
# 1092                                                DND
# 1093                                     Honor of Kings
#
#      Where is your dream vacation spot?
# 0                       Southern France
# 1                          My apartment
# 2                                 Italy
# 3                 Denali National Park
# 4                             australia
# ...                                 ...
# 1089                             Alaska
# 1090          NYC during Christmas time
# 1091                          Mountains
# 1092                              Beach
# 1093                              Japan
#
# [1094 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df" in vars()), "This is not the Hello Dataset you're looking for. Check the URL."
assert("Favorite way to spend your free time?" in df), "This is not the Hello Dataset you're looking for. Check the URL."
assert(len(df) >= 1094), "This is not the Hello Dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Finding Yourself
# Before finding people you are **similar to**, you have to find **yourself** - literally!
#
# ### Puzzle 1.1: Your Row
# In the following cell, write the Python code to create a **new** DataFrame with only yourself, named `df_me`:
#
# Helpful Notes:
#
# - If you cannot find yourself in the Hello Dataset, try adding a space after your name within the string.  Sometimes your phone will add a space if you press the auto-complete on your phone's keyboard.
# - If you did not fill out the Hello Survey, pick one of your TAs, CAs, or Professor Karle or Wade! Their names of course staff in the survey start with either `CA`, `TA`, or `Prof.`, in the format of "TA Jake", "TA Mallory", "Prof. Karle", "Prof. Wade", etc

# %%
df_me = df[df["Name"] == "Beichen"]
df_me
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 836  Beichen  Y12                                 Heads
#
#     Is this your first year at UIUC?  \
# 836               First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 836                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 836                        Morning                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 836                 No                          Summer
#
#     Are you a business major?  ...  \
# 836                        No  ...
#
#     Besides the US, what country would you like to live in?  \
# 836                                     China, England
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 836                         Buke                               running
#
#     What genre of music do you like the most?  \
# 836                                 Classical
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 836                                                cat
#
#     What do you think is the hardest major at UIUC?  \
# 836                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 836                      Yonezu Kenshi                                    INS
#
#     What is your favorite game to play (either video game or IRL)?  \
# 836                                               FIFA
#
#     Where is your dream vacation spot?
# 836                             Franch
#
# [1 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df_me" in vars()), "Make sure you named the DataFrame with just you `df_me`."
assert("Favorite way to spend your free time?" in df_me), "Your `df_me` should have the same columns as our `df`."
assert(len(df_me.columns.to_list()) == 150), "Your `df_me` should have the same number of columns as our original `df`."
assert(len(df_me) == 1), "Your `df_me` should only have one row: yourself."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Dataframe vs. Series
#
# Before we continue, a brief lesson on some of the data types you'll encounter in this class.
#
# In `pandas`, there are three data structures we will be using, two of which you have already seen:
#
# - A **DataFrame** is similar to an Excel sheet. It contains zero or more rows and zero or more columns. It can contain up to an unlimited number of rows and columns and is the basic data structure we've worked with from the start of this course
#
# - A **GroupBy** is a grouping of rows within a DataFrame. This "three dimensional data" requires us to use `agg` to reduce it back down to a DataFrame - which you've been doing in homeworks and labs thus far!
#
# - A **Series** is a single row with zero or more values (columns). You can think of a DataFrame as a collection of **Series** objects. When we deal with a single row, we will usually want to deal with a **Series** instead of a **one row DataFrame**.
#
# In this lab, we will learn how to convert from a **one row DataFrame** to a **Series**, but here's a quick rundown on how to convert from types:

# %% [markdown]
# ### Converting Types
#
# The `pandas` library makes it easy to convert between a **Series**, **DataFrame**, and **GroupBy**.
#
# - From a **Series** (`row`) to a **DataFrame**:
#     - `row.to_frame()`
# - From a **DataFrame** (`df`) to a **GroupBy**:
#     - `df.groupby('columnName')` -- (You know this already!)
# - From a **GroupBy** (`group`) to a **DataFrame**:
#     - `group.agg( function )` -- (You know this already!)
# - From a **DataFrame** (`df`) to a **Series**:
#     - `df.iloc[0]`, if the DataFrame has one row
#
# See this guide, https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/dataframe-loc-vs-iloc/, for more information about `iloc[]`.

# %% [markdown]
# ### Puzzle 1.2: Transform your row into a Series
# Using the correct function from above, **transform** the `df_me` row containing only you from a **one-row DataFrame** into a **Series**.
#
# Make sure the Series is named `my_row` (this will match up with code we provide you with later):

# %%
my_row = df_me.iloc[0]
my_row
# Out:
# Name                                                                         Beichen
# Lab                                                                              Y12
# When flipping a coin, heads or tails?                                          Heads
# Is this your first year at UIUC?                                  First Year at UIUC
# Is your favorite ice cream flavor chocolate or vanilla?                    Chocolate
#                                                                          ...
# What do you think is the hardest major at UIUC?                                   CS
# Who is your favorite music artist?                                     Yonezu Kenshi
# What's your favorite social media app?                                           INS
# What is your favorite game to play (either video game or IRL)?                  FIFA
# Where is your dream vacation spot?                                            Franch
# Name: 836, Length: 150, dtype: object

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('my_row' in vars()), "Your series should be named `my_row`."
assert(type(my_row) == pd.core.series.Series), "Make sure you've correctly converted your one-row DataFrame into a Series..."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Choosing Your Columns

# %% [markdown]
# Before we begin, we have to think about our approach to finding your DISCOVERY twin.
#
# You may have noticed our Hello Dataset has **more than 100 questions**. Instead of finding the most similar person to you using **every question**, we'll pick out a few questions to analyze.
#
# **But first, we need to revisit the questions.**
#
# Recall the function `df.columns.tolist()`. To recap, this command will list **all of the columns** (in this case, our questions) in a DataFrame.
#
# Use `df.columns.tolist()` in the cell below.
#
# <br>
#
# **Viewing the Full Output**: When you do that, you will likely see the message:
#
# > Output exceeds the __size limit__. Open the full output data __in a text editor__.
#
# If you do, click the **in a text editor** link to open the whole list in a new tab of VSCode.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night? ',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?',
#  'Do you prefer milk chocolate or dark chocolate?',
#  'Do you prefer Italian or Mexican food?',
#  'Do you prefer sugar cookies or chocolate chip cookies?',
#  'Can you speak a second language fluently?',
#  'Do you prefer Math or English?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Do you prefer day or night?',
#  'Do you prefer lecture halls or small classes? ',
#  'Are you in-state or out of state?',
#  'Do you typically shower in the morning or at night?',
#  'Does money buy happiness?',
#  'Do you prefer to party or stay in?',
#  'McDonalds or Burger King?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you drink a cup of coffee every morning?',
#  'Do you drink coffee?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you prefer brownies or cookies?',
#  'Google Docs or Microsoft Word?',
#  'Do you like horror movies?',
#  'Do you have programming experience?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Do you like your dorm?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Are you from the Chicagoland area?',
#  'Does your NetID end with an even or odd number?',
#  'Are you wearing something on your wrist currently?',
#  'Is it called Futbol or Soccer?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have exactly one sibling?',
#  'Are you taking any other computer science classes?',
#  'In the DISCOVERY lecture, do you sit in the front 50% or back 50%?',
#  'Do you sit on the left or right side in lecture?',
#  'Pick a random number 1-10. is the number you picked odd or even?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer to study alone or in groups?',
#  'Do you prefer Apple or Google maps?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Is your UIN an even number?',
#  'Were you born before or after 2006?',
#  "Would you sit behind the driver or the passenger seat when you're at the back seat in a car?",
#  'Did you come from a big or a small high school?',
#  "Are you shorter or taller than 5'7 (170cm)?",
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer go to school by bus or by walking?',
#  'Did the chicken or the egg come first?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer Coca-Cola or Sprite?',
#  'Do you prefer coffee or tea?',
#  'Dawn or Dusk?',
#  'Would you rather drown or burn to death?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer group projects or solo assignments?',
#  'Do you prefer a hot location vacation or a cold vacation location?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Are you taking stat107 for your major or not?',
#  'Who is a better poet?',
#  "Do you prefer 'light mode' or 'dark mode' on your technological devices?",
#  'Do you have long hair or short hair?',
#  'Do you prefer morning or afternoon classes?',
#  'Do you prefer indoor or outdoor activities?',
#  'Do you prefer Pizza or Cheeseburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Do you prefer running or walking?',
#  'What soccer team is better?',
#  'Do you prefer strawberries or blueberries?',
#  'Do you live in student housing (i.e. dorms) or private housing (i.e. apartments)?',
#  'Do you like the warm or cold weather better?',
#  'Would you rather your head be the size of a watermelon or an orange?',
#  'Do you prefer wings or burgers?',
#  'Do you prefer Playstation or Xbox?',
#  'Y or N?',
#  'Do you like the color yellow?',
#  'Do you like ranch?',
#  'Were you born in the United States?',
#  'Do you consider yourself an international student?',
#  'Have you ever been outside of United States?',
#  'Have you ever had COVID-19?',
#  'Do you like chocolate?',
#  'Do you like spicy food?',
#  'What\'s the color of "the dress"? (See it here: https://en.wikipedia.org/wiki/The_dress)',
#  'Are you taking 16 or more credit hours this semester?',
#  'Do you have siblings?',
#  'Did you play sports in high school? ',
#  'Does pineapple belong on pizza?',
#  'Is purple your favorite color? ',
#  'Do you like bananas?',
#  'Do you like Champaign?',
#  'Do you like rainy weather?',
#  'Does the First Letter of your last name Start with a Letter A-L Including L? ',
#  'Do you like Durian?',
#  'Pick between TRUE or FALSE.',
#  'Do you prefer watching basketball or football games?',
#  'Do you prefer caramel or sprinkle toppings on your ice cream?',
#  'Can you swim? ',
#  'Would you rather be to see the future or change the past?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ### Puzzle 1.3: Choosing Your Columns
# From the above list of **columns** (questions), choose **at least 12 questions** to work with moving forward. Please use **only questions with binary answers** for this part of the analysis :)
#
# These will be the questions used to **calculate your similarity** to other people in DISCOVERY! Feel free to include more if you'd like.
#
# Store them as a **list** of **strings** named `questions` in the Python cell below:

# %%
questions = ['When flipping a coin, heads or tails?',
 'Is this your first year at UIUC?',
 'Is your favorite ice cream flavor chocolate or vanilla?',
 'Do you prefer even or odd numbers?',
 'Do you have a pet?',
 'Do you prefer summer or winter?',
 'Are you a business major?',
 'Do you prefer Movies or TV shows?',
 'Do you prefer pizza or hamburgers?',
 'Are you male or female?',
 'Do you prefer the color Blue or Red?',
 'Do you like Taylor Swifts music?',
 'Do you prefer sweet or salty food?',
 'Do you eat breakfast in the mornings?',
 'Ice cream or cake? ',
 'Are you an upperclassman or an underclassman?',
 'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
 'Is the day of the month of your birthday an odd or even number?',
 'Do you speak a second language?',
 'Do you prefer cats or dogs?',
 'Are you a morning person or a night person?',
 'Do you enjoy reading?',
]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('questions' in vars()), "Please name your list of questions `questions`."
assert(type(questions) == list and type(questions[0]) == str), "Make sure your `questions` variable is a list of strings."
assert(len(questions) >= 12), "Do you have at least 12 questions in your columns list?"
for q in questions:
   assert(q in df), "Double check that you've copied each question correctly. The question texts should match up EXACTLY with the output from `df.columns.to_list()`."
for q in questions:
   assert(len(df[q].value_counts()) == 2), "Make sure that you've only included questions with binary answers in your columns list."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: The Similarity Function

# %% [markdown]
# Now that we have chosen the **questions** we'd like to evaluate, it's time to create a **function** to calculate a similarity value for each person, or each row in `df`.
#
# In lecture, remember learning that a Python **function** takes an **input** in and **returns** a **value**.
#
# For this specific function, we will take a **row** and calculate a **similarity score** for that row.
#
# But first, **print your list of questions** using the Python cell below for reference:

# %%
questions
# Out:
# ['When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?']

# %% [markdown]
# ### Puzzle 2.1: The Similarity Function
#
# In the code below, you will find an outline for a `similarity` function that returns a similarity score:
#
# > ```py
# > def similarity(row):
# >     # This function will keep track of a `score` of how similar two rows are with each other.
# >     # The score begins at zero and we will add to it every time a row matches.
# >     score = 0
# >
# >     # This if statement below checks to see if the `row` shares your choice between Coffee and Tea
# >     # - If the values are the same (==), we add one to the score.
# >     # - If the values are NOT the same, the `score = score + 1` line is skipped.
# >     if row["Coffee or Tea?"] == my_row["Coffee or Tea?"]:
# >         score = score + 1
# >
# >     # Finally, return the `score`.
# >     # ...this line (the return statement) should always be the LAST line.
# >     return score
# > ```
#
# Using this same function structure, complete your `similarity` function below **using the questions you picked out earlier**.  This will require you to write **one if statement** for each question you selected:

# %%
def similarity(row):
    # Your Task Here:
    # Repeat the above syntax many imes for EACH question (column) that you have chosen in your list
    # IMPORTANT: Make sure to keep our lines all at this same level of tabbing out from the start.    
    # ALSO IMPORTANT: Delete or thereplace the "Coffee or Tea?" question!
    #                 (unless you'v decided that is one of your evaluating questions). 
    score = 0 

    if row["When flipping a coin, heads or tails?"] == my_row["When flipping a coin, heads or tails?"]:
        score = score + 1
    if row["Is this your first year at UIUC?"] == my_row["Is this your first year at UIUC?"]:
        score = score + 1
    if row["Is your favorite ice cream flavor chocolate or vanilla?"] == my_row["Is your favorite ice cream flavor chocolate or vanilla?"]:
        score = score + 1
    if row["Do you prefer even or odd numbers?"] == my_row["Do you prefer even or odd numbers?"]:
        score = score + 1
    if row["Do you have a pet?"] == my_row["Do you have a pet?"]:
        score = score + 1
    if row["Do you prefer summer or winter?"] == my_row["Do you prefer summer or winter?"]:
        score = score + 1
    if row["Are you a business major?"] == my_row["Are you a business major?"]:
        score = score + 1
    if row["Do you prefer Movies or TV shows?"] == my_row["Do you prefer Movies or TV shows?"]:
        score = score + 1
    if row["Do you prefer pizza or hamburgers?"] == my_row["Do you prefer pizza or hamburgers?"]:
        score = score + 1
    if row["Are you male or female?"] == my_row["Are you male or female?"]:
        score = score + 1
    if row["Do you prefer the color Blue or Red?"] == my_row["Do you prefer the color Blue or Red?"]:
        score = score + 1
    if row["Do you like Taylor Swifts music?"] == my_row["Do you like Taylor Swifts music?"]:
        score = score + 1
    if row["Do you prefer sweet or salty food?"] == my_row["Do you prefer sweet or salty food?"]:
        score = score + 1
    if row["Do you eat breakfast in the mornings?"] == my_row["Do you eat breakfast in the mornings?"]:
        score = score + 1
    if row["Ice cream or cake? "] == my_row["Ice cream or cake? "]:
        score = score + 1
    if row["Are you an upperclassman or an underclassman?"] == my_row["Are you an upperclassman or an underclassman?"]:
        score = score + 1
    if row["As you walk in from the back, do you prefer to sit on the left or right side of lecture?"] == my_row["As you walk in from the back, do you prefer to sit on the left or right side of lecture?"]:
        score = score + 1
    if row["Is the day of the month of your birthday an odd or even number?"] == my_row["Is the day of the month of your birthday an odd or even number?"]:
        score = score + 1
    if row["Do you speak a second language?"] == my_row["Do you speak a second language?"]:
        score = score + 1
    if row["Do you prefer cats or dogs?"] == my_row["Do you prefer cats or dogs?"]:
        score = score + 1
    if row["Are you a morning person or a night person?"] == my_row["Are you a morning person or a night person?"]:
        score = score + 1
    if row["Do you enjoy reading?"] == my_row["Do you enjoy reading?"]:
        score = score + 1

    return score

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(similarity(my_row) == len(questions) or similarity(my_row) == my_row[questions].count()), "Ensure you've added all the questions from your list and ONLY questions from your list correctly to your similarity function."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Applying the Similarity Function
# Now that you've properly defined the similarity function, we need to **apply** it to the rest of the Hello Dataset DataFrame so we can produce a **similarity score** for each person who took the survey!
#
# Luckily, `pandas` provides a useful function for our use case: `df.apply()`.
#
# Quick lesson: `df.apply(some_function)` applies a pre-defined function named `some_function` along an axis of your DataFrame.
#
# Because we want to run our `similarity` function on all **rows**, when you call `df.apply()`, ensure you use **`axis=1`**. This would look something like:
#
# > ```py
# > df["score"] = df.apply(some_function, axis=1)
# > ```
#
# Using the above explanation as reference, **add a column** named `Similarity Score` to your original DataFrame that contains the value after running your `similarity` function you defined earlier across all rows:

# %%
df["Similarity Score"] = df.apply(similarity, axis=1)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('Similarity Score' in df), "Make sure you've named and added the Similarity Score column to your original df."
assert(df['Similarity Score'].dtype == 'int64'), "Double check that you've called the similarity function correctly in your df.apply()."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Finding your Twin(s)

# %% [markdown]
# Your last column `Similarity Score` in `df` is now a metric (a measurement) of how **similar** you are to everyone else in the class, based on the **questions you've chosen**!
#
# Finally, we can do analytical Data Science!

# %% [markdown]
# ### Puzzle 3.1: Your Twin in 107
#
# Using the Python cell below, find the **person most similar to you in the entire course** (having the largest `Similarity Score`).
#
# Note that **you should be most similar to yourself** (you will always match yourself)! This is not the right answer. Find the person with the highest score ***aside from yourself***.  *(There is a chance there can be multiple people tied as the person most similar to you and that's okay!)*

# %%
df_similar = df.nlargest(2, "Similarity Score")
df_similar
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 836  Beichen  Y12                                 Heads
# 5      Jaden  Y34                                 Heads
#
#     Is this your first year at UIUC?  \
# 836               First Year at UIUC
# 5                 First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 836                                          Chocolate
# 5                                            Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 836                        Morning                               Even
# 5                          Morning                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 836                 No                          Summer
# 5                   No                          Summer
#
#     Are you a business major?  ... What is your favorite color?  \
# 836                        No  ...                         Buke
# 5                          No  ...                         blue
#
#     Favorite way to spend your free time?  \
# 836                               running
# 5                       talk with friends
#
#     What genre of music do you like the most?  \
# 836                                 Classical
# 5                                         pop
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 836                                                cat
# 5                                                  dog
#
#     What do you think is the hardest major at UIUC?  \
# 836                                              CS
# 5                                                CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 836                      Yonezu Kenshi                                    INS
# 5                                keshi                                 wechat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 836                                               FIFA
# 5                                                  LOL
#
#     Where is your dream vacation spot? Similarity Score
# 836                             Franch               22
# 5                                china               20
#
# [2 rows x 151 columns]

# %% [markdown]
# ### Puzzle 3.2: Your Lab Twin
#
# Now, chances are your twin isn't in your lab section. Because we conveniently have our similarity function applied to the **entire** set of responses to the survey in the `Similarity Score` column, we can create smaller DataFrames to answer more questions.
#
# We want to find the person most similar to you in **your lab section**, otherwise known as your lab twin! We can create a new DataFrame to answer this question.
#
# However, some of your CAs and TAs, who are part of your lab section, are in more than one lab section! Those who have multiple sections have `Y##, Y##...` in their Sections column. How can we create a DataFrame that includes the CAs and TAs who are in more than one lab section? Python saves the day again.
#
# #### **The `contains` Function**
# In Python, the `contains` function can be used to check if a specific **substring** is present in a **string**.
#
# This will come in handy for us, because we can see if `Y##` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with everyone in your lab section: `df_section`. Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Lab` column of `df` to a **string** by using `.str`.

# %%
df_section = df[(df['Lab'].str.contains("Y12"))]
df_section
# Out:
#              Name          Lab When flipping a coin, heads or tails?  \
# 31            Liz          Y12                                 Heads
# 69           Reva          Y12                                 Tails
# 109          Ryan          Y12                                 Tails
# 156        Christ          Y12                                 Heads
# 228        Taylor          Y12                                 Heads
# 247   Christopher          Y12                                 Heads
# 286      Xiaoxue           Y12                                 Heads
# 347       Weihang          Y12                                 Heads
# 425        Yujian          Y12                                 Heads
# 490           Ivy          Y12                                 Heads
# 653          Luke          Y12                                 Heads
# 747           Odi          Y12                                 Heads
# 806          Noah          Y12                                 Heads
# 808         Dylan          Y12                                 Heads
# 836       Beichen          Y12                                 Heads
# 844         Chris          Y12                                 Heads
# 859          Jake          Y12                                 Tails
# 871          Zach          Y12                                 Heads
# 898          Brie          Y12                                 Tails
# 923         Erdem          Y12                                 Tails
# 927         Olive          Y12                                 Heads
# 929        Ruofan          Y12                                 Heads
# 956        Preity          Y12                                 Heads
# 961         Peter          Y12                                 Heads
# 962        CA Jai     Y02, Y12                                 Heads
# 965    CA Jessica  Y01 and Y12                                 Heads
# 984       Patrick          Y12                                 Heads
# 1027        Advay          Y12                                 Heads
# 1041       Damian          Y12                                 Tails
# 1047       Nathan          Y12                                 Tails
# 1070    TA Kunlun     Y12, Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 31                     Not First Year
# 69                     Not First Year
# 109                    Not First Year
# 156                    Not First Year
# 228                    Not First Year
# 247                    Not First Year
# 286                    Not First Year
# 347                    Not First Year
# 425                    Not First Year
# 490                    Not First Year
# 653                    Not First Year
# 747                    Not First Year
# 806                    Not First Year
# 808                First Year at UIUC
# 836                First Year at UIUC
# 844                First Year at UIUC
# 859                    Not First Year
# 871                First Year at UIUC
# 898                    Not First Year
# 923                    Not First Year
# 927                    Not First Year
# 929                    Not First Year
# 956                    Not First Year
# 961                    Not First Year
# 962                    Not First Year
# 965                    Not First Year
# 984                First Year at UIUC
# 1027                   Not First Year
# 1041                   Not First Year
# 1047                   Not First Year
# 1070               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 31                                              Vanilla
# 69                                            Chocolate
# 109                                             Vanilla
# 156                                             Vanilla
# 228                                             Vanilla
# 247                                           Chocolate
# 286                                             Vanilla
# 347                                           Chocolate
# 425                                             Vanilla
# 490                                             Vanilla
# 653                                           Chocolate
# 747                                             Vanilla
# 806                                             Vanilla
# 808                                           Chocolate
# 836                                           Chocolate
# 844                                             Vanilla
# 859                                             Vanilla
# 871                                             Vanilla
# 898                                           Chocolate
# 923                                             Vanilla
# 927                                           Chocolate
# 929                                           Chocolate
# 956                                             Vanilla
# 961                                             Vanilla
# 962                                           Chocolate
# 965                                           Chocolate
# 984                                           Chocolate
# 1027                                            Vanilla
# 1041                                            Vanilla
# 1047                                          Chocolate
# 1070                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 31                            Night                                Odd
# 69                          Morning                               Even
# 109                         Morning                               Even
# 156                         Morning                               Even
# 228                           Night                                Odd
# 247                           Night                               Even
# 286                           Night                               Even
# 347                         Morning                               Even
# 425                           Night                                Odd
# 490                         Morning                                Odd
# 653                           Night                                Odd
# 747                           Night                               Even
# 806                         Morning                               Even
# 808                           Night                               Even
# 836                         Morning                               Even
# 844                         Morning                               Even
# 859                           Night                               Even
# 871                           Night                                Odd
# 898                             NaN                                Odd
# 923                           Night                                Odd
# 927                           Night                               Even
# 929                           Night                               Even
# 956                           Night                               Even
# 961                           Night                               Even
# 962                           Night                                Odd
# 965                           Night                               Even
# 984                         Morning                               Even
# 1027                          Night                                Odd
# 1041                          Night                                Odd
# 1047                          Night                               Even
# 1070                        Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 31                  Yes                          Winter
# 69                  Yes                          Summer
# 109                 Yes                          Summer
# 156                  No                          Summer
# 228                  No                          Winter
# 247                  No                          Summer
# 286                  No                          Summer
# 347                  No                          Winter
# 425                  No                          Winter
# 490                  No                          Summer
# 653                 Yes                          Winter
# 747                  No                          Summer
# 806                  No                          Winter
# 808                 Yes                          Winter
# 836                  No                          Summer
# 844                 Yes                          Summer
# 859                  No                          Summer
# 871                 Yes                          Summer
# 898                 Yes                          Summer
# 923                  No                          Summer
# 927                  No                          Summer
# 929                 Yes                          Summer
# 956                  No                          Winter
# 961                 Yes                          Summer
# 962                 Yes                          Summer
# 965                  No                          Summer
# 984                  No                          Winter
# 1027                Yes                          Winter
# 1041                 No                          Winter
# 1047                Yes                          Summer
# 1070                Yes                          Summer
#
#      Are you a business major?  ... What is your favorite color?  \
# 31                          No  ...                   Periwinkle
# 69                         Yes  ...                         Pink
# 109                         No  ...                        Green
# 156                         No  ...                          Red
# 228                         No  ...                   chartreuse
# 247                         No  ...                          red
# 286                         No  ...                         Pink
# 347                         No  ...                         Pink
# 425                         No  ...                        White
# 490                         No  ...                         Bule
# 653                         No  ...                         Blue
# 747                         No  ...                         Pink
# 806                         No  ...                        Green
# 808                        Yes  ...                         Blue
# 836                         No  ...                         Buke
# 844                        Yes  ...                         blue
# 859                         No  ...                          Red
# 871                        Yes  ...                        Green
# 898                         No  ...                        Green
# 923                         No  ...                       purple
# 927                         No  ...                         Pink
# 929                         No  ...                        white
# 956                         No  ...                        Black
# 961                         No  ...                         Blue
# 962                         No  ...                         Blue
# 965                         No  ...                     sky blue
# 984                        Yes  ...                        Green
# 1027                        No  ...                       Maroon
# 1041                        No  ...                        Black
# 1047                        No  ...                         gray
# 1070                        No  ...                         blue
#
#      Favorite way to spend your free time?  \
# 31                                Sleeping
# 69                                 Reading
# 109                     With my girlfriend
# 156                                Lifting
# 228                                 eating
# 247                  Watching movies/shows
# 286     Spending time with my best friends
# 347                                  Sleep
# 425                        Play video game
# 490                                  sleep
# 653                               Sleeping
# 747                      Watching tv show
# 806                                  Sleep
# 808                          With friends
# 836                                running
# 844                               Chilling
# 859                        Watching movies
# 871                               Swimming
# 898                        With my friends
# 923                                  Sleep
# 927                  Hang out with friends
# 929                               sleeping
# 956             Spending time with friends
# 961                                 Sports
# 962                                 Soccer
# 965                                reading
# 984                         Playing Guitar
# 1027                    Listening to music
# 1041                         Skateboarding
# 1047                                gaming
# 1070                                  game
#
#      What genre of music do you like the most?  \
# 31                                         R&B
# 69                                         R&B
# 109                                 Indie Rock
# 156                                        R&B
# 228                                    screamo
# 247                                        rap
# 286                                   Romantic
# 347                                     Hiphop
# 425                                  pop music
# 490                                       Kpop
# 653                                       Rock
# 747                                        Rap
# 806                                  Classical
# 808                                    Hip hop
# 836                                  Classical
# 844                                    hip hop
# 859                                    Country
# 871                                      Indie
# 898                                Alternative
# 923                                      Indie
# 927                                        Pop
# 929                                       Pop
# 956                                        Pop
# 961                                        Rap
# 962                                        EDM
# 965                                  indie pop
# 984                                      Indie
# 1027                                       All
# 1041                                 Folk Punk
# 1047                                     k rnb
# 1070                                      jazz
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 31                                             Capybara
# 69                                              Unicorn
# 109                                            Elephant
# 156                                                Lion
# 228                                                 cat
# 247                                                 pig
# 286                                                 Cat
# 347                                                Lion
# 425                                               tiger
# 490                                                 Cat
# 653                                          Sea Turtle
# 747                                             Lioness
# 806                                           Red Panda
# 808                                               Eagle
# 836                                                 cat
# 844                                                 dog
# 859                                               Eagle
# 871                                             Dolphin
# 898                                             Penguin
# 923                                           Groundhog
# 927                                                 Cat
# 929                                                 dog
# 956                                                 NaN
# 961                                                 Dog
# 962                                                 Dog
# 965                                                 cat
# 984                                    Gorilla. Gorilla
# 1027                                               Wolf
# 1041                                             Turtle
# 1047                                              panda
# 1070                                               egal
#
#      What do you think is the hardest major at UIUC?  \
# 31                             Aerospace Engineering
# 69                                           Physics
# 109                             Computer Engineering
# 156                                     Engineering
# 228                                               IB
# 247                                 Computer science
# 286                                               CS
# 347                                               CS
# 425                                              ECE
# 490                                               CS
# 653                           Electrical Engineering
# 747                          Electrical engineering
# 806                                   Bioengineering
# 808                                         Engineer
# 836                                               CS
# 844                            aerospace engineering
# 859                           Mechanical Engineering
# 871                                      Engineering
# 898                                              ECE
# 923                            Aerospace Engineering
# 927                           Aerospace Engineering
# 929                       Maths and computer science
# 956                             Computer Engineering
# 961                                Computer Science
# 962                                              ECE
# 965                                              ECE
# 984                           Electrical Engineering
# 1027                          Electrical Engineering
# 1041                          Electrical Engineering
# 1047                                          mech e
# 1070                                              cs
#
#      Who is your favorite music artist?  \
# 31                                  SZA
# 69                           The Marias
# 109                         Mac Demarco
# 156                              J cole
# 228                               dream
# 247                        Lil uzi vert
# 286                        Taylor Swift
# 347                           Beethoven
# 425                           Seventeen
# 490                        Taylor Swift
# 653                        Dire Straits
# 747                 Megan Thee Stallion
# 806                            Kendrick
# 808                      Kendrick lamar
# 836                       Yonezu Kenshi
# 844                           kid laroi
# 859                          Luke Combs
# 871                          Zach Bryan
# 898                         Tame Impala
# 923                              Clairo
# 927                   Sabrina Carpenter
# 929                                Kygo
# 956                        Selena Gomez
# 961                        Travis Scott
# 962                            Coldplay
# 965                         post malone
# 984                             Mt. Joy
# 1027                   Adele & Coldplay
# 1041                      Pat the Bunny
# 1047                                 iu
# 1070                           Coldplay
#
#      What's your favorite social media app?  \
# 31                                   TikTok
# 69                                Instagram
# 109                                LinkedIn
# 156                               Instagram
# 228                                 google+
# 247                               instagram
# 286                                  TikTok
# 347                                  WeChat
# 425                                  Wechat
# 490                                  WeChat
# 653                                    none
# 747                               Instagram
# 806                                 YouTube
# 808                                Snapchat
# 836                                     INS
# 844                               instagram
# 859                               Instagram
# 871                                  TikTok
# 898                                 Tik Tok
# 923                               Instagram
# 927                               Instagram
# 929                                  WeChat
# 956                               Instagram
# 961                               Instagram
# 962                                  Reddit
# 965                               instagram
# 984                               Instagram
# 1027                              Instagram
# 1041                                Twitter
# 1047                                  insta
# 1070                                 Wechat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 31                                             Valorant
# 69                                           Mario Cart
# 109                                          Pickleball
# 156                                                 Uno
# 228                                                 tag
# 247                                          Basketball
# 286                                           Eggyparty
# 347                                   Honor of the King
# 425                                          video game
# 490                                          video game
# 653                                 Rock Paper Scissors
# 747                                        Candy Crush
# 806                                            Valorant
# 808                                            Football
# 836                                                FIFA
# 844                                                ncaa
# 859                                       Rocket League
# 871                                          Elden Ring
# 898                                           Vollyball
# 923                                           Crossword
# 927                                               Cards
# 929                                            Palworld
# 956                                              Tennis
# 961                                            Fortnite
# 962                                               Catan
# 965                                               catan
# 984                                            Football
# 1027                                             Futbol
# 1041                                          Minecraft
# 1047                                           valorant
# 1070                                          overwatch
#
#      Where is your dream vacation spot? Similarity Score
# 31                          Switzerland               10
# 69                                 Bali               12
# 109                     Washington D.C.               12
# 156                              Mexico               11
# 228                        north dakota               11
# 247                              Greece               13
# 286                               Miami               14
# 347                              Hawaii               11
# 425                               China               15
# 490                                  LA               12
# 653                       St. John USVI               11
# 747                              Brazil               11
# 806                               Japan               12
# 808                             Iceland               13
# 836                              Franch               22
# 844                             Bahamas               13
# 859                                Cabo               12
# 871                               Japan               11
# 898                              Vienna               11
# 923                               Italy               13
# 927                               Tokyo               16
# 929                            New York               11
# 956                         Switzerland               14
# 961                                Alps               12
# 962                                Bali               10
# 965                               japan               14
# 984                               Italy               13
# 1027                   Barcelona, Spain               11
# 1041                            Ireland               12
# 1047                              korea               13
# 1070                                 CA               16
#
# [31 rows x 151 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_section' in vars()), "Your DataFrame of your section should be named 'df_section'."
assert((len(df_section) >= 15) and (len(df_section) <= 37)), "Make sure you've filtered your DataFrame correctly to only include your section."
assert(len(df_section.columns.to_list()) == 151), "You should have all of the questions columns and the Similarity Score column in df_section."
assert any(all(df_section['Lab'].str.contains(f"Y{i:02}")) for i in range(1, 37)), "Make sure you've filtered your DataFrame correctly to only include your section."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.3: Your Lab Twin!
#
# Similarly to Puzzle 3.1, find your lab section twin (the person in your lab section who has the **highest Similarity Score** to you).

# %%
df_similarsection = df_section.nlargest(2,"Similarity Score")
df_similarsection
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 836  Beichen  Y12                                 Heads
# 927    Olive  Y12                                 Heads
#
#     Is this your first year at UIUC?  \
# 836               First Year at UIUC
# 927                   Not First Year
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 836                                          Chocolate
# 927                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 836                        Morning                               Even
# 927                          Night                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 836                 No                          Summer
# 927                 No                          Summer
#
#     Are you a business major?  ... What is your favorite color?  \
# 836                        No  ...                         Buke
# 927                        No  ...                         Pink
#
#     Favorite way to spend your free time?  \
# 836                               running
# 927                 Hang out with friends
#
#     What genre of music do you like the most?  \
# 836                                 Classical
# 927                                       Pop
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 836                                                cat
# 927                                                Cat
#
#     What do you think is the hardest major at UIUC?  \
# 836                                              CS
# 927                          Aerospace Engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 836                      Yonezu Kenshi                                    INS
# 927                  Sabrina Carpenter                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 836                                               FIFA
# 927                                              Cards
#
#     Where is your dream vacation spot? Similarity Score
# 836                             Franch               22
# 927                              Tokyo               16
#
# [2 rows x 151 columns]

# %% [markdown]
# #### **➡️ Right now, once you have that person, find them in lab!**<br>➡️ *(If they're not here, look for the next similar person.)*
#
# Help them get up to this point in the lab and let them find their DISCOVERY twin!  *(Are you twins of each other?)*
#
# ➡️ Once you are **BOTH** to this section, introduce yourself and your DISCOVERY lab section "twin" to your lab TA. <br>
# ➡️ Make sure you know what your "Similarity Score" to your twin is! <br>
# ➡️ If you do this introduction to your TA **in-person during your lab section, you will earn +1 EC**! :)
#
# Note that there may be ties in `Similarity Score` due to the usage of only parts of the dataset. If you're curious, you can go back and **add more questions** to your `questions` list and `similarity(row)` function, rerunning the code to have more evaluative similarity scores.

# %% [markdown]
# ### Analysis: True Twin?
#
# **Q1: If you picked twelve or more other questions to evaluate similarity, do you think you'd find a different twin in the course overall?  Explain, in at least one complete sentence, why you think this is the case.**

# %% [markdown]
# *(Yes, I think if I picked twelve or more additional questions to evaluate similarity, it will be more possible for me to find a different twin because including more variables would capture a broader range of personal preferences, traits, and behaviors, increasing the chances of identifying someone with a higher overall similarity score across all aspects. The larger question set provides more dimensions for comparison, making it more likely to find someone with closer responses.)*

# %% [markdown]
# ### Puzzle 3.4: The Course Staff
# A lot of wonderful course staff work together to bring you all the content for Data Science Discovery.
#
# The course staff of 107 consists of the **Professors, TAs, and CAs**. As you saw in the previous parts, they've all completed the Hello Survey too!
#
# Their response under the `Name` column is standardized and follows these formats:
# - `Prof. [Name]`,
# - `TA [Name]`, or
# - `CA [Name]`
#
# The `contains` function will come in handy for us once again, because we can see if `"CA"`, `"TA"`, or `"Prof."` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with just the course staff: `df_staff`. Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.*

# %%
df_staff = df[
  (df['Name'].str.contains('CA')) |
  (df['Name'].str.contains('TA'))|   # Also include all TAs
  (df['Name'].str.contains('Prof'))     # Don't forget Karle and Wade!
] 
df_staff
# IMPORTANT: Make sure you include a whitespace in "CA "" and "TA "" so that people with those
# #          letters in their name aren't included.  Whitespace matters! :)
# Out:
#               Name            Lab When flipping a coin, heads or tails?  \
# 1         TA Tyler  Y07, Y10, Y20                                 Tails
# 18     Prof. Karle       AL1, AL2                                 Heads
# 48       CA Prisha       Y35, Y28                                 Tails
# 61     TA Mitchell       Y09, Y30                                 Tails
# 71      CA Sangjun            Y08                                 Heads
# 78         CA Eric       Y15, Y31                                 Heads
# 81        CA Amaan      Y30 , Y36                                 Heads
# 108       CA Paige       Y32, Y33                                 Heads
# 117       CA Sneha            Y06                                 Tails
# 119      CA Gerald       Y09, Y21                                 Tails
# 132     Prof. Wade       AL1, AL2                                 Tails
# 161   CA Victoria             Y03                                 Heads
# 184      CA Alyssa  Y02, Y04, Y24                                 Heads
# 186       CA Renee       Y17, Y21                                 Heads
# 190        CA Emma       Y03, Y20                                 Heads
# 195    CA Qiran Hu       Y18, Y28                                 Tails
# 230      CA Amelie       Y13, Y14                                 Heads
# 268         CA Ram       Y30, Y35                                 Tails
# 311       CA Ethan            Y22                                 Heads
# 342         CA Mia  Y01, Y04, Y10                                 Heads
# 353        TA Eric  Y17, Y08, Y36                                 Heads
# 361      CA Sophia  Y16, Y02, Y32                                 Tails
# 368        CA Urvi       Y19, Y23                                 Heads
# 379        TA Sony       Y16, Y18                                 Heads
# 451       CA Elise       Y11, Y33                                 Heads
# 462       CA Talia  Y16, Y24, Y10                                 Heads
# 473     CA Lyndsey            Y08                                 Heads
# 491       TA Ruize       Y28, Y34                                 Heads
# 506       CA Subbu       Y15, Y23                                 Heads
# 517      CA Eliana  Y07, Y19, Y26                                 Tails
# 520     TA Mallory  Y05, Y13, Y23                                 Heads
# 526        TA Evan  Y02, Y04, Y14                                 Heads
# 548        CA Gabe            Y13                                 Heads
# 635     TA Shuning        Y15 Y27                                 Heads
# 723      TA Nathan  Y06, Y33, Y35                                 Tails
# 726      CA Lauren       Y27, Y32                                 Heads
# 738      CA Areeba            Y29                                 Heads
# 785        TA Jake  Y01, Y03, Y24                                 Heads
# 819       CA Irene            Y13                                 Heads
# 896        CA Emma  Y27, Y05, Y25                                 Heads
# 907      CA Anagha       Y17, Y22                                 Tails
# 962         CA Jai       Y02, Y12                                 Heads
# 965     CA Jessica    Y01 and Y12                                 Heads
# 968       TA Omkar       Y11, Y26                                 Heads
# 1008     TA Mukhil       Y22, Y32                                 Heads
# 1061       CA Soph    Y05 Y07 Y14                                 Heads
# 1062        CA Sri       Y18, Y34                                 Heads
# 1063      CA Maddy            Y36                                 Heads
# 1064     CA Anchal       Y31, Y19                                 Heads
# 1065      TA Deeya       Y19, Y29                                 Tails
# 1066      CA Bella            Y34                                 Heads
# 1068       CA Lara       Y19, Y20                                 Tails
# 1069      TA Jimmy            Y21                                 Tails
# 1070     TA Kunlun       Y12, Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 18                     Not First Year
# 48                     Not First Year
# 61                     Not First Year
# 71                     Not First Year
# 78                     Not First Year
# 81                     Not First Year
# 108                    Not First Year
# 117                    Not First Year
# 119                    Not First Year
# 132                    Not First Year
# 161                    Not First Year
# 184                    Not First Year
# 186                    Not First Year
# 190                    Not First Year
# 195                First Year at UIUC
# 230                    Not First Year
# 268                    Not First Year
# 311                    Not First Year
# 342                    Not First Year
# 353                    Not First Year
# 361                    Not First Year
# 368                    Not First Year
# 379                    Not First Year
# 451                    Not First Year
# 462                    Not First Year
# 473                    Not First Year
# 491                    Not First Year
# 506                    Not First Year
# 517                    Not First Year
# 520                    Not First Year
# 526                    Not First Year
# 548                    Not First Year
# 635                    Not First Year
# 723                First Year at UIUC
# 726                    Not First Year
# 738                    Not First Year
# 785                    Not First Year
# 819                    Not First Year
# 896                    Not First Year
# 907                    Not First Year
# 962                    Not First Year
# 965                    Not First Year
# 968                    Not First Year
# 1008                   Not First Year
# 1061                   Not First Year
# 1062                   Not First Year
# 1063                   Not First Year
# 1064                   Not First Year
# 1065                   Not First Year
# 1066                   Not First Year
# 1068                   Not First Year
# 1069               First Year at UIUC
# 1070               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                             Chocolate
# 18                                            Chocolate
# 48                                              Vanilla
# 61                                            Chocolate
# 71                                              Vanilla
# 78                                              Vanilla
# 81                                            Chocolate
# 108                                             Vanilla
# 117                                             Vanilla
# 119                                             Vanilla
# 132                                             Vanilla
# 161                                             Vanilla
# 184                                           Chocolate
# 186                                             Vanilla
# 190                                           Chocolate
# 195                                           Chocolate
# 230                                             Vanilla
# 268                                             Vanilla
# 311                                             Vanilla
# 342                                           Chocolate
# 353                                           Chocolate
# 361                                             Vanilla
# 368                                             Vanilla
# 379                                           Chocolate
# 451                                             Vanilla
# 462                                           Chocolate
# 473                                           Chocolate
# 491                                                 NaN
# 506                                           Chocolate
# 517                                           Chocolate
# 520                                           Chocolate
# 526                                           Chocolate
# 548                                             Vanilla
# 635                                           Chocolate
# 723                                             Vanilla
# 726                                           Chocolate
# 738                                             Vanilla
# 785                                             Vanilla
# 819                                           Chocolate
# 896                                             Vanilla
# 907                                             Vanilla
# 962                                           Chocolate
# 965                                           Chocolate
# 968                                           Chocolate
# 1008                                            Vanilla
# 1061                                          Chocolate
# 1062                                            Vanilla
# 1063                                            Vanilla
# 1064                                            Vanilla
# 1065                                          Chocolate
# 1066                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
# 1070                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                               Even
# 18                            Night                               Even
# 48                          Morning                               Even
# 61                          Morning                               Even
# 71                            Night                               Even
# 78                            Night                               Even
# 81                          Morning                                Odd
# 108                         Morning                               Even
# 117                           Night                                Odd
# 119                           Night                               Even
# 132                           Night                                Odd
# 161                           Night                               Even
# 184                         Morning                                Odd
# 186                           Night                               Even
# 190                           Night                               Even
# 195                           Night                               Even
# 230                           Night                               Even
# 268                           Night                                Odd
# 311                           Night                               Even
# 342                           Night                               Even
# 353                         Morning                               Even
# 361                           Night                                Odd
# 368                           Night                                Odd
# 379                         Morning                               Even
# 451                           Night                               Even
# 462                           Night                               Even
# 473                         Morning                               Even
# 491                             NaN                                NaN
# 506                         Morning                                Odd
# 517                           Night                                Odd
# 520                         Morning                                Odd
# 526                         Morning                                Odd
# 548                           Night                               Even
# 635                           Night                               Even
# 723                           Night                                Odd
# 726                         Morning                               Even
# 738                         Morning                                Odd
# 785                           Night                                Odd
# 819                         Morning                                Odd
# 896                           Night                               Even
# 907                           Night                               Even
# 962                           Night                                Odd
# 965                           Night                               Even
# 968                         Morning                               Even
# 1008                          Night                               Even
# 1061                          Night                               Even
# 1062                          Night                               Even
# 1063                        Morning                               Even
# 1064                          Night                                Odd
# 1065                          Night                               Even
# 1066                        Morning                               Even
# 1068                          Night                               Even
# 1069                          Night                               Even
# 1070                        Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                    No                          Winter
# 18                   No                          Summer
# 48                   No                          Summer
# 61                   No                          Summer
# 71                   No                          Winter
# 78                   No                          Winter
# 81                  Yes                          Winter
# 108                  No                          Summer
# 117                  No                          Winter
# 119                 Yes                          Summer
# 132                 Yes                          Winter
# 161                 Yes                          Summer
# 184                 Yes                          Winter
# 186                  No                          Winter
# 190                  No                          Summer
# 195                 Yes                          Summer
# 230                 Yes                          Summer
# 268                  No                          Summer
# 311                 Yes                          Summer
# 342                  No                          Summer
# 353                 Yes                          Summer
# 361                  No                          Summer
# 368                  No                          Summer
# 379                 Yes                          Summer
# 451                 Yes                          Summer
# 462                  No                          Summer
# 473                 Yes                          Summer
# 491                 Yes                          Winter
# 506                  No                          Summer
# 517                 Yes                          Winter
# 520                 Yes                          Summer
# 526                  No                          Winter
# 548                 Yes                          Summer
# 635                  No                          Winter
# 723                 Yes                          Summer
# 726                 Yes                          Summer
# 738                  No                          Winter
# 785                 Yes                          Summer
# 819                  No                          Summer
# 896                 Yes                          Summer
# 907                  No                          Summer
# 962                 Yes                          Summer
# 965                  No                          Summer
# 968                  No                          Summer
# 1008                Yes                          Summer
# 1061                Yes                          Winter
# 1062                 No                          Winter
# 1063                 No                          Summer
# 1064                 No                          Winter
# 1065                Yes                          Winter
# 1066                Yes                          Summer
# 1068                 No                          Summer
# 1069                 No                          Summer
# 1070                Yes                          Summer
#
#      Are you a business major?  ... What is your favorite color?  \
# 1                           No  ...                       Orange
# 18                          No  ...                         pink
# 48                          No  ...                      Purple
# 61                          No  ...                        Green
# 71                          No  ...                        Green
# 78                          No  ...                         blue
# 81                          No  ...                    Dark Blue
# 108                         No  ...                        green
# 117                         No  ...                       Yellow
# 119                         No  ...                         Blue
# 132                         No  ...                       Purple
# 161                        Yes  ...                         pink
# 184                         No  ...                       purple
# 186                        Yes  ...                         Pink
# 190                         No  ...                        Green
# 195                         No  ...                         pink
# 230                        Yes  ...                       purple
# 268                         No  ...                         Blue
# 311                         No  ...                       indigo
# 342                         No  ...                     Lavender
# 353                         No  ...                         Blue
# 361                         No  ...                       Purple
# 368                         No  ...                   Periwinkle
# 379                         No  ...                       purple
# 451                         No  ...                         Pink
# 462                         No  ...                          Red
# 473                         No  ...                          red
# 491                         No  ...                         Blue
# 506                         No  ...                         Blue
# 517                         No  ...                         Blue
# 520                         No  ...                        green
# 526                         No  ...                         Grey
# 548                        Yes  ...                         blue
# 635                         No  ...                   light blue
# 723                         No  ...                         Blue
# 726                         No  ...                        green
# 738                         No  ...                         Blue
# 785                         No  ...                       Yellow
# 819                         No  ...                       Purple
# 896                         No  ...                         Pink
# 907                         No  ...                         Blue
# 962                         No  ...                         Blue
# 965                         No  ...                     sky blue
# 968                         No  ...                         teal
# 1008                        No  ...                   Lime green
# 1061                        No  ...                          Red
# 1062                        No  ...                         Blue
# 1063                        No  ...                         pink
# 1064                        No  ...                         blue
# 1065                        No  ...                          Red
# 1066                        No  ...                       purple
# 1068                        No  ...                       beige
# 1069                        No  ...                        Black
# 1070                        No  ...                         blue
#
#            Favorite way to spend your free time?  \
# 1                                       Terraria
# 18                                 water skiing!
# 48                                 With friends
# 61                                         Sleep
# 71                                         Games
# 78                                         Sleep
# 81                                         Party
# 108                                     reading
# 117                                 With Friends
# 119                                Playing music
# 132                                  Programming
# 161                                     friends
# 184                                      reading
# 186                                          Nap
# 190                                 With friends
# 195                                       Coding
# 230                                 brainrotting
# 268                                        Sleep
# 311                         hangout with friends
# 342                     hanging out with friends
# 353                                       Skiing
# 361                                    sleeping
# 368                                 with friends
# 379                                 With friends
# 451                                With friends
# 462                            Reading or hiking
# 473                                     shopping
# 491                                  Play guitar
# 506                    Do something with friends
# 517                                      Readinf
# 520                                       biking
# 526                               Being outdoors
# 548                                       sports
# 635              chill at home watching tv shows
# 723                               With my family
# 726                                      Cooking
# 738                         Crocheting or hiking
# 785                                    GeoGuessr
# 819                                      Reading
# 896                                     Outside!
# 907                      Spend time with friends
# 962                                       Soccer
# 965                                      reading
# 968                                     sleeping
# 1008                                      Eating
# 1061                                With friends
# 1062                                       Sleep
# 1063                                 working out
# 1064                                       sleep
# 1065  Spending time with my friends doing crafts
# 1066                                     outside
# 1068                                     reading
# 1069                              Watching shows
# 1070                                        game
#
#      What genre of music do you like the most?  \
# 1                                     Pop rock
# 18                                         pop
# 48                                         Rap
# 61                                         Rap
# 71                                   Reggaeton
# 78                                        cpop
# 81                                     Hip Hop
# 108                                alternative
# 117                                        Pop
# 119                                       Rock
# 132                                        Pop
# 161                                       kpop
# 184                                        pop
# 186                                      indie
# 190                                Alternative
# 195                                    country
# 230                                    pop rap
# 268                                       KPOP
# 311                                  indie pop
# 342                                        Pop
# 353                                  Classical
# 361                                      indie
# 368                                        Pop
# 379                                  Indie Pop
# 451                                  Indie pop
# 462                                       Rock
# 473                                        pop
# 491                                    NeoSoul
# 506                                        NaN
# 517                                        Pop
# 520                                   acoustic
# 526                                 Indie Rock
# 548                                       folk
# 635                                       kpop
# 723                                    Country
# 726                                        RnB
# 738                                        Pop
# 785                                       Folk
# 819                                      Indie
# 896                                    Alt Pop
# 907                                        Pop
# 962                                        EDM
# 965                                  indie pop
# 968                                  bollywood
# 1008                                       R&B
# 1061                                     Indie
# 1062                                 Indie Pop
# 1063                                       pop
# 1064                                       Pop
# 1065                                      Kpop
# 1066                                       pop
# 1068                               Riot grrrl
# 1069                                       Pop
# 1070                                      jazz
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Bee
# 18                                                sloth
# 48                                            Elephant
# 61                                              Dolphin
# 71                                                  Cat
# 78                                                panda
# 81                                               Falcon
# 108                                          Blue heron
# 117                                                Orca
# 119                                             Giraffe
# 132                                                 Fox
# 161                                                Owl
# 184                                             giraffe
# 186                                                 cat
# 190                                          Chameleon
# 195                                                 Cat
# 230                                                 Cat
# 268                                                 Cat
# 311                                       purple martin
# 342                                             Giraffe
# 353                                                 Fox
# 361                                             cheetah
# 368                                                Lynx
# 379                                             Dolphin
# 451                                                Wolf
# 462                                                 Fox
# 473                                            shih tzu
# 491                                              Beaver
# 506                                          Polar Bear
# 517                                           Sea otter
# 520                                               raven
# 526                                               Horse
# 548                                          polar bear
# 635                                                 dog
# 723                                               Tiger
# 726                                       Spider Monkey
# 738                                            Elephant
# 785                                                 Dog
# 819                                                 Cow
# 896                                           Centipede
# 907                                              Turtle
# 962                                                 Dog
# 965                                                 cat
# 968                                                 NaN
# 1008                                            Penguin
# 1061                                              Shark
# 1062                                           Capybara
# 1063                                                cat
# 1064                                              Panda
# 1065                                   I would be a cat
# 1066                                          butterfly
# 1068                                        sea anemone
# 1069                                              Panda
# 1070                                               egal
#
#      What do you think is the hardest major at UIUC?  \
# 1                               Chemical Engineering
# 18                                  Computer Science
# 48                             Computer engineering
# 61                                              Math
# 71                                       Engineering
# 78                             Computer Engineering
# 81                              Computer Engineering
# 108                                            music
# 117                                     Computer Eng
# 119                                          Physics
# 132                                 Computer Science
# 161                                              ECE
# 184                                              ECE
# 186                                      Mathematics
# 190                                 Computer Science
# 195                                 Computer Science
# 230                                   Bioengineering
# 268                             Computer Engineering
# 311                             computer engineering
# 342                                          Physics
# 353                               Neural Engineering
# 361                                              ECE
# 368                                          Biochem
# 379              Electrical and Computer Engineering
# 451                                             Eecs
# 462                                        Math + CS
# 473                                 computer science
# 491                                              ECE
# 506                             Computer Engineering
# 517                             Computer Engineering
# 520                                              NaN
# 526                                      Mathematics
# 548                                      Engineering
# 635                                              ece
# 723                                          Physics
# 726                                 Computer Science
# 738                                              ECE
# 785                                               CS
# 819                                              ECE
# 896                            Being a Woman in STEM
# 907                                              ECE
# 962                                              ECE
# 965                                              ECE
# 968                                              ECE
# 1008                            Computer Engineering
# 1061                             Bioengineering + CS
# 1062                                             ECE
# 1063                                        comp sci
# 1064                                              CS
# 1065                                             ECE
# 1066                            chemical engineering
# 1068                                        Physics
# 1069                                         Physics
# 1070                                              cs
#
#      Who is your favorite music artist?  \
# 1                            Billy Joel
# 18                         Taylor Swift
# 48                                Drake
# 61                                   Ye
# 71                            Bad bunny
# 78                               Laufey
# 81                               Weeknd
# 108                         The Wallows
# 117                        Jensen McRae
# 119                      Kendrick Lamar
# 132                        Taylor Swift
# 161                             Enhypen
# 184                          charli xcx
# 186                       Chappell Roan
# 190                             TV Girl
# 195                            Aventura
# 230                                  Ye
# 268                            NewJeans
# 311                  Tyler, the Creator
# 342                        taylor swift
# 353                           Beethoven
# 361                     Phoebe Bridgers
# 368                        Taylor Swift
# 379                         Still Woozy
# 451                        Taylor swift
# 462                       Fleetwood Mac
# 473                       gracie abrams
# 491                         Seiji Igusa
# 506                             Anirudh
# 517                      Itzhak Perlman
# 520                            Bon Iver
# 526                         Hilary Hahn
# 548                               caamp
# 635                          black pink
# 723                     Vampire Weekend
# 726                        Faye Webster
# 738                          Ed Sheeran
# 785                      Tyler Childers
# 819                              Laufey
# 896                       Chappell Roan
# 907                        Harry Styles
# 962                            Coldplay
# 965                         post malone
# 968                        arijit singh
# 1008                           Coldplay
# 1061                                BTS
# 1062                       Don Toliver
# 1063                       taylor swift
# 1064                        The Weekend
# 1065                                SZA
# 1066                       taylor swift
# 1068                            Slant 6
# 1069                         Kanye West
# 1070                           Coldplay
#
#      What's your favorite social media app?  \
# 1                                    Reddit
# 18                                Instagram
# 48                               Instagram
# 61                                  Twitter
# 71                                   Tiktok
# 78                                instagram
# 81                                Instagram
# 108                               pinterest
# 117                                  Tumblr
# 119                                 Discord
# 132                                 YouTube
# 161                                  TikTok
# 184                                 twitter
# 186                         Little Red Book
# 190                                  TikTok
# 195                               Instagram
# 230                                 YouTube
# 268                                 Discord
# 311                               instagram
# 342                               Instagram
# 353                               Instagram
# 361                               Instagram
# 368                                  TikTok
# 379                                 Spotify
# 451                               Pinterest
# 462                               Goodreads
# 473                               instagram
# 491                                  Wechat
# 506                               Instagram
# 517                               Goodreads
# 520                                     NaN
# 526                              Instsagram
# 548                               Instagram
# 635                                     xhs
# 723                                       X
# 726                               Instagram
# 738                               Instagram
# 785                                  Tiktok
# 819                               Instagram
# 896                                  TikTok
# 907                                 YouTube
# 962                                  Reddit
# 965                               instagram
# 968                               instagram
# 1008                              Instagram
# 1061                                 TikTok
# 1062                                 TikTok
# 1063                                 tiktok
# 1064                                 TikTok
# 1065                              Instagram
# 1066                              pinterest
# 1068                                Reddit
# 1069                                Discord
# 1070                                 Wechat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Terraria
# 18                                           volleyball
# 48                                                 2048
# 61                                                Poker
# 71                                             Fortnite
# 78                                             valorant
# 81                                             Football
# 108                                            solitare
# 117                                                Clue
# 119                                          Beat Saber
# 132                                            Factorio
# 161                                          overcooked
# 184                                      stardew valley
# 186                                               Hades
# 190                                               Omori
# 195                                               Chess
# 230                                              Sims 4
# 268                                          Basketball
# 311                                          basketball
# 342                                           Rummy 500
# 353                                           Badminton
# 361                                            Fortnite
# 368                                         Dutch Blitz
# 379                                         Contact 123
# 451                                           Pinochle
# 462                            Star Wars Battlefront II
# 473                                          pickleball
# 491                                   League of Legends
# 506                                            Sequence
# 517                                             Pokémon
# 520                                        a short hike
# 526                                                 NaN
# 548                                              tennis
# 635                                                wgry
# 723                                       NCAA Football
# 726                                            Monopoly
# 738                                                 Tag
# 785                                      Spectre Divide
# 819                                               Cards
# 896                                              Trivia
# 907                                      Need For Speed
# 962                                               Catan
# 965                                               catan
# 968                                                fifa
# 1008                                             Tennis
# 1061                                          Minecraft
# 1062                         We're Not Really Strangers
# 1063                                        super mario
# 1064                                           Snake.io
# 1065                                        Royal Match
# 1066                             pretty pretty princess
# 1068                                          Oxenfree
# 1069                                              Poker
# 1070                                          overwatch
#
#      Where is your dream vacation spot? Similarity Score
# 1                          My apartment                9
# 18                         The Maldives               12
# 48                                Italy               12
# 61                               Hawaii               13
# 71                          Switzerland               12
# 78                                Japan               14
# 81                                 Rome               12
# 108                             Moracco               11
# 117                               Tahoe                6
# 119                               Japan               14
# 132                              Acadia                8
# 161                         south korea                8
# 184                               italy                8
# 186                               Kyoto               12
# 190                              Greece               13
# 195                           New York                15
# 230                               Italy                8
# 268                           Singapore               11
# 311                              norway               10
# 342                               Japan               15
# 353               Giant City State Park               16
# 361                              greece               12
# 368                              Greece               12
# 379                         New Zealand               13
# 451                               Kenya               10
# 462                Prince Edward Island               12
# 473                               italy               13
# 491                          My bedroom               11
# 506                              Alaska               15
# 517                            Scotland                9
# 520                  alas i do not know               12
# 526                         Scandinavia               12
# 548                              greece               10
# 635           Switzerland Skiing resort               11
# 723             German Christmas Market                9
# 726                               Tokyo               11
# 738                              Hawaii               15
# 785                             Jamaica                9
# 819                         New Zealand               12
# 896                      National Parks               13
# 907                               India               11
# 962                                Bali               10
# 965                               japan               14
# 968                               spain               11
# 1008                         Antarctica               11
# 1061                            Croatia               13
# 1062                       New Zealand                12
# 1063                             greece               15
# 1064                            Iceland                9
# 1065                           Thailand                8
# 1066                             vienna               11
# 1068                              Japan               11
# 1069                              Japan               14
# 1070                                 CA               16
#
# [54 rows x 151 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.4 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_staff' in vars()), "Your DataFrame of course staff should be named 'df_staff'."
assert(len(df_staff) == 54), "Check you've added all the course staff correctly."
assert(len(df_staff.columns.to_list()) == 151), "You should have all of the questions columns and the Similarity Score column in df_staff." 

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.5: Course Staff Twin!
#
# Now that we have the course staff responses in `df_staff`, find your course staff twin (the staff member who has the **highest Similarity Score** to you).

# %%
large = df_staff.nlargest(1,"Similarity Score")
large
# Out:
#         Name            Lab When flipping a coin, heads or tails?  \
# 353  TA Eric  Y17, Y08, Y36                                 Heads
#
#     Is this your first year at UIUC?  \
# 353                   Not First Year
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 353                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 353                        Morning                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 353                Yes                          Summer
#
#     Are you a business major?  ... What is your favorite color?  \
# 353                        No  ...                         Blue
#
#     Favorite way to spend your free time?  \
# 353                                Skiing
#
#     What genre of music do you like the most?  \
# 353                                 Classical
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 353                                                Fox
#
#     What do you think is the hardest major at UIUC?  \
# 353                              Neural Engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 353                          Beethoven                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 353                                          Badminton
#
#     Where is your dream vacation spot? Similarity Score
# 353              Giant City State Park               16
#
# [1 rows x 151 columns]

# %% [markdown]
# ### Analysis: Final Reflection
#
# **Q2: Do you think our method of finding similar people is effective? Why or why not? What could improve it?**

# %% [markdown]
# *(I think this method is not really effective, becuase I need to copy and paste each question. It can be improved by using the code like "for index in range(len(questions)) q = question[index] if my_row[q] == row[q]: score += 1", by using this code, there is no need to type a lot, just as the following code shown)*

# %%
def similarity(row, my_row):
    questions = [
        "When flipping a coin, heads or tails?",
        "Is this your first year at UIUC?",
        "Is your favorite ice cream flavor chocolate or vanilla?",
        "Do you prefer even or odd numbers?",
        "Do you have a pet?",
        "Do you prefer summer or winter?",
        "Are you a business major?",
        "Do you prefer Movies or TV shows?",
        "Do you prefer pizza or hamburgers?",
        "Are you male or female?",
        "Do you prefer the color Blue or Red?",
        "Do you like Taylor Swifts music?",
        "Do you prefer sweet or salty food?",
        "Do you eat breakfast in the mornings?",
        "Ice cream or cake? ",
        "Are you an upperclassman or an underclassman?",
        "As you walk in from the back, do you prefer to sit on the left or right side of lecture?",
        "Is the day of the month of your birthday an odd or even number?",
        "Do you speak a second language?",
        "Do you prefer cats or dogs?",
        "Are you a morning person or a night person?",
        "Do you enjoy reading?"
    ]
    
    score = 0  
    for q in questions:
        if my_row[q] == row[q]:
            score += 1  

    return score

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
