# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "KUNIVN"
ca1_name = "JAI"
ca2_name = "Jessica"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Christ Goncalves"
partner1_netid = "christg2"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "Odi Ogbuefi"
partner2_netid = "ouo2"
partner2_inYourGroupLastWeek = "yes"

partner3_name = "Beichen Hu"
partner3_netid = "beichen7"
partner3_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(✏️Edit this cell to add your group's question.✏️)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa24.csv")
df
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 1      Prof. Wade  AL1, AL2                                 Tails
# 2        Angelina       Y13                                 Tails
# 3        TA Tyler       Y07                                 Tails
# 4          Sneha        Y17                                 Tails
# ...           ...       ...                                   ...
# 1065     Man Geun       Y04                                 Heads
# 1066     CA Elise  Y11, Y33                                 Heads
# 1067      Chinmay       Y11                                 Heads
# 1068        Bowen       Y25                                 Heads
# 1069     kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 4                  First Year at UIUC
# ...                               ...
# 1065                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 4                                               Vanilla
# ...                                                 ...
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 4                             Night                               Even
# ...                             ...                                ...
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 4                    No                          Summer
# ...                 ...                             ...
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                          Yes  ...
# ...                        ...  ...
# 1065                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 4                                                Canada
# ...                                                 ...
# 1065                                              Korea
# 1066                                            England
# 1067                                              India
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# ...                           ...                                   ...
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 4                                     Pop Rock
# ...                                        ...
# 1065                                       Pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 4                                               Penguin
# ...                                                 ...
# 1065                                                Dog
# 1066                                               Wolf
# 1067                                                Dog
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 4                                   Computer Science
# ...                                              ...
# 1065                                              CS
# 1066                                            Eecs
# 1067                                Computer Science
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 4                       Imagine Dragons
# ...                                 ...
# 1065                                 IU
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 4                                 Instagram
# ...                                     ...
# 1065                              Instagram
# 1066                              Pinterest
# 1067                              Instagram
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 4                                            Beat Saber
# ...                                                 ...
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1067                                             Tennis
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 4                                 Italy
# ...                                 ...
# 1065                             Cancun
# 1066                              Kenya
# 1067                             Monaco
# 1068                              Tokyo
# 1069                            iceland
#
# [1070 rows x 150 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night? ',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?',
#  'Do you prefer milk chocolate or dark chocolate?',
#  'Do you prefer Italian or Mexican food?',
#  'Do you prefer sugar cookies or chocolate chip cookies?',
#  'Can you speak a second language fluently?',
#  'Do you prefer Math or English?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Do you prefer day or night?',
#  'Do you prefer lecture halls or small classes? ',
#  'Are you in-state or out of state?',
#  'Do you typically shower in the morning or at night?',
#  'Does money buy happiness?',
#  'Do you prefer to party or stay in?',
#  'McDonalds or Burger King?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you drink a cup of coffee every morning?',
#  'Do you drink coffee?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you prefer brownies or cookies?',
#  'Google Docs or Microsoft Word?',
#  'Do you like horror movies?',
#  'Do you have programming experience?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Do you like your dorm?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Are you from the Chicagoland area?',
#  'Does your NetID end with an even or odd number?',
#  'Are you wearing something on your wrist currently?',
#  'Is it called Futbol or Soccer?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have exactly one sibling?',
#  'Are you taking any other computer science classes?',
#  'In the DISCOVERY lecture, do you sit in the front 50% or back 50%?',
#  'Do you sit on the left or right side in lecture?',
#  'Pick a random number 1-10. is the number you picked odd or even?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer to study alone or in groups?',
#  'Do you prefer Apple or Google maps?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Is your UIN an even number?',
#  'Were you born before or after 2006?',
#  "Would you sit behind the driver or the passenger seat when you're at the back seat in a car?",
#  'Did you come from a big or a small high school?',
#  "Are you shorter or taller than 5'7 (170cm)?",
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer go to school by bus or by walking?',
#  'Did the chicken or the egg come first?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer Coca-Cola or Sprite?',
#  'Do you prefer coffee or tea?',
#  'Dawn or Dusk?',
#  'Would you rather drown or burn to death?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer group projects or solo assignments?',
#  'Do you prefer a hot location vacation or a cold vacation location?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Are you taking stat107 for your major or not?',
#  'Who is a better poet?',
#  "Do you prefer 'light mode' or 'dark mode' on your technological devices?",
#  'Do you have long hair or short hair?',
#  'Do you prefer morning or afternoon classes?',
#  'Do you prefer indoor or outdoor activities?',
#  'Do you prefer Pizza or Cheeseburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Do you prefer running or walking?',
#  'What soccer team is better?',
#  'Do you prefer strawberries or blueberries?',
#  'Do you live in student housing (i.e. dorms) or private housing (i.e. apartments)?',
#  'Do you like the warm or cold weather better?',
#  'Would you rather your head be the size of a watermelon or an orange?',
#  'Do you prefer wings or burgers?',
#  'Do you prefer Playstation or Xbox?',
#  'Y or N?',
#  'Do you like the color yellow?',
#  'Do you like ranch?',
#  'Were you born in the United States?',
#  'Do you consider yourself an international student?',
#  'Have you ever been outside of United States?',
#  'Have you ever had COVID-19?',
#  'Do you like chocolate?',
#  'Do you like spicy food?',
#  'What\'s the color of "the dress"? (See it here: https://en.wikipedia.org/wiki/The_dress)',
#  'Are you taking 16 or more credit hours this semester?',
#  'Do you have siblings?',
#  'Did you play sports in high school? ',
#  'Does pineapple belong on pizza?',
#  'Is purple your favorite color? ',
#  'Do you like bananas?',
#  'Do you like Champaign?',
#  'Do you like rainy weather?',
#  'Does the First Letter of your last name Start with a Letter A-L Including L? ',
#  'Do you like Durian?',
#  'Pick between TRUE or FALSE.',
#  'Do you prefer watching basketball or football games?',
#  'Do you prefer caramel or sprinkle toppings on your ice cream?',
#  'Can you swim? ',
#  'Would you rather be to see the future or change the past?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your binary question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  df.columns[97]
analysis_column
# Out:
# 'Do you prefer running or walking?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 1053), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[['Do you prefer running or walking?']]
# Out:
#      Do you prefer running or walking?
# 0                              Walking
# 1                              Walking
# 2                              Walking
# 3                              Walking
# 4                              Walking
# ...                                ...
# 1065                           Running
# 1066                           Walking
# 1067                           Walking
# 1068                           Walking
# 1069                           Walking
#
# [1070 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == 'Running']
df1
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 5          Gage       Y10                                 Heads
# 7         Jaden       Y34                                 Heads
# 11        Najam       Y20                                 Tails
# 19        Brady       Y16                                 Heads
# 22         Yash       Y25                                 Heads
# ...         ...       ...                                   ...
# 1046      harry       Y99                                 Heads
# 1057   CA Bella       Y34                                 Heads
# 1061  TA Kunlun  Y12, Y25                                 Heads
# 1062     Eunice       Y28                                 Heads
# 1065   Man Geun       Y04                                 Heads
#
#      Is this your first year at UIUC?  \
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 11                 First Year at UIUC
# 19                 First Year at UIUC
# 22                 First Year at UIUC
# ...                               ...
# 1046                   Not First Year
# 1057                   Not First Year
# 1061               First Year at UIUC
# 1062               First Year at UIUC
# 1065                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 5                                               Vanilla
# 7                                             Chocolate
# 11                                            Chocolate
# 19                                              Vanilla
# 22                                                  NaN
# ...                                                 ...
# 1046                                          Chocolate
# 1057                                          Chocolate
# 1061                                          Chocolate
# 1062                                          Chocolate
# 1065                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 5                             Night                               Even
# 7                           Morning                               Even
# 11                            Night                                Odd
# 19                          Morning                                Odd
# 22                          Morning                                Odd
# ...                             ...                                ...
# 1046                        Morning                               Even
# 1057                        Morning                               Even
# 1061                        Morning                               Even
# 1062                          Night                               Even
# 1065                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 5                   Yes                          Winter
# 7                    No                          Summer
# 11                   No                          Winter
# 19                   No                          Summer
# 22                  Yes                          Winter
# ...                 ...                             ...
# 1046                Yes                          Summer
# 1057                Yes                          Summer
# 1061                Yes                          Summer
# 1062                 No                          Summer
# 1065                 No                          Winter
#
#      Are you a business major?  ...  \
# 5                           No  ...
# 7                           No  ...
# 11                          No  ...
# 19                         Yes  ...
# 22                         Yes  ...
# ...                        ...  ...
# 1046                       Yes  ...
# 1057                        No  ...
# 1061                        No  ...
# 1062                       Yes  ...
# 1065                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 5                                               Canada
# 7                                                 japan
# 11                                             pakistan
# 19                                                Italy
# 22                                                India
# ...                                                 ...
# 1046                                              china
# 1057                                            sweeden
# 1061                                              China
# 1062                                        south korea
# 1065                                              Korea
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 5                           Green                   Fishing or Hunting
# 7                            blue                     talk with friends
# 11                          Black                                 Chill
# 19                           Blue                               Golfing
# 22                           blue                       Watching movies
# ...                           ...                                   ...
# 1046                          red                                 games
# 1057                       purple                               outside
# 1061                         blue                                  game
# 1062                         blue                         playing piano
# 1065                         Blue                           Playstation
#
#      What genre of music do you like the most?  \
# 5                                 Grunge Rock
# 7                                          pop
# 11                                         rap
# 19                                     Country
# 22                                 Punjabi rap
# ...                                        ...
# 1046                                    hiphop
# 1057                                       pop
# 1061                                      jazz
# 1062                                      kpop
# 1065                                       Pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 5                                                 Bear
# 7                                                   dog
# 11                                                horse
# 19                                                 Lion
# 22                                                 lion
# ...                                                 ...
# 1046                                               lion
# 1057                                          butterfly
# 1061                                               egal
# 1062                                              sloth
# 1065                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 5                                              Math
# 7                                                 CS
# 11                                         Chemistry
# 19                                  Computer Science
# 22                                           physics
# ...                                              ...
# 1046                                            chem
# 1057                            chemical engineering
# 1061                                              cs
# 1062                                     engineering
# 1065                                              CS
#
#      Who is your favorite music artist?  \
# 5                            Jim Croce
# 7                                 keshi
# 11                           juice wrld
# 19                           Zach Bryan
# 22                        playboi carti
# ...                                 ...
# 1046                             taylor
# 1057                       taylor swift
# 1061                           Coldplay
# 1062                                IVE
# 1065                                 IU
#
#      What's your favorite social media app?  \
# 5                                    Tiktok
# 7                                    wechat
# 11                                instagram
# 19                                 Snapchat
# 22                                instagram
# ...                                     ...
# 1046                                  music
# 1057                              pinterest
# 1061                                 Wechat
# 1062                              instagram
# 1065                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 5                                           Titanfall 2
# 7                                                   LOL
# 11                                    Football (soccer)
# 19                                    Pickup Basketball
# 22                         Star Wars Jedi: Fallen Order
# ...                                                 ...
# 1046                                                lol
# 1057                             pretty pretty princess
# 1061                                          overwatch
# 1062                                            genshin
# 1065                                              NBA2k
#
#      Where is your dream vacation spot?
# 5                 Denali National Park
# 7                                 china
# 11                            mountains
# 19                                 Rome
# 22                             Maldives
# ...                                 ...
# 1046                               home
# 1057                             vienna
# 1061                                 CA
# 1062                              Italy
# 1065                             Cancun
#
# [252 rows x 150 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == 'Walking']
df2
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 1      Prof. Wade  AL1, AL2                                 Tails
# 2        Angelina       Y13                                 Tails
# 3        TA Tyler       Y07                                 Tails
# 4          Sneha        Y17                                 Tails
# ...           ...       ...                                   ...
# 1064       Wesley       Y02                                 Tails
# 1066     CA Elise  Y11, Y33                                 Heads
# 1067      Chinmay       Y11                                 Heads
# 1068        Bowen       Y25                                 Heads
# 1069     kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 4                  First Year at UIUC
# ...                               ...
# 1064                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 4                                               Vanilla
# ...                                                 ...
# 1064                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 4                             Night                               Even
# ...                             ...                                ...
# 1064                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 4                    No                          Summer
# ...                 ...                             ...
# 1064                 No                          Summer
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                          Yes  ...
# ...                        ...  ...
# 1064                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 4                                                Canada
# ...                                                 ...
# 1064                                              japan
# 1066                                            England
# 1067                                              India
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# ...                           ...                                   ...
# 1064                         blue                                 sleep
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 4                                     Pop Rock
# ...                                        ...
# 1064                                       pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 4                                               Penguin
# ...                                                 ...
# 1064                                         dog/ camel
# 1066                                               Wolf
# 1067                                                Dog
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 4                                   Computer Science
# ...                                              ...
# 1064                                         english
# 1066                                            Eecs
# 1067                                Computer Science
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 4                       Imagine Dragons
# ...                                 ...
# 1064                         juice wrld
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 4                                 Instagram
# ...                                     ...
# 1064                                youtube
# 1066                              Pinterest
# 1067                              Instagram
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 4                                            Beat Saber
# ...                                                 ...
# 1064                                        brawl stars
# 1066                                           Pinochle
# 1067                                             Tennis
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 4                                 Italy
# ...                                 ...
# 1064                              japan
# 1066                              Kenya
# 1067                             Monaco
# 1068                              Tokyo
# 1069                            iceland
#
# [815 rows x 150 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# *(Total:1067/1070 = 99.7%  Walking:815/1067=76.4% Running:252/1067=23.6% )*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# *(Yes, this answer really suprise me, I never thought that there are so many people prefer walking rather than running )*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# *(I donot think my question is cloest to a perfect 50/50 percent, there are much more people prefer walkinh)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 833      Kavya  Y26                                 Tails
# 932     Nathan  Y10                                 Tails
# 287        Ria  Y22                                 Tails
# 870   Mahitha   Y08                                 Heads
# 1025      Siyu  Y01                                 Heads
# ...        ...  ...                                   ...
# 757        Tia  Y23                                 Heads
# 489      Jacob  Y04                                 Heads
# 1007    Samuel  Y13                                 Heads
# 327       Juno  Y17                                 Heads
# 145     krissy  Y07                                 Heads
#
#      Is this your first year at UIUC?  \
# 833                First Year at UIUC
# 932                First Year at UIUC
# 287                First Year at UIUC
# 870                First Year at UIUC
# 1025                   Not First Year
# ...                               ...
# 757                First Year at UIUC
# 489                    Not First Year
# 1007               First Year at UIUC
# 327                    Not First Year
# 145                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 833                                             Vanilla
# 932                                           Chocolate
# 287                                           Chocolate
# 870                                             Vanilla
# 1025                                            Vanilla
# ...                                                 ...
# 757                                             Vanilla
# 489                                           Chocolate
# 1007                                            Vanilla
# 327                                             Vanilla
# 145                                             Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 833                           Night                               Even
# 932                           Night                               Even
# 287                           Night                               Even
# 870                           Night                               Even
# 1025                          Night                               Even
# ...                             ...                                ...
# 757                           Night                               Even
# 489                           Night                               Even
# 1007                          Night                               Even
# 327                         Morning                               Even
# 145                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 833                  No                          Winter
# 932                 Yes                          Summer
# 287                  No                          Winter
# 870                  No                          Summer
# 1025                Yes                          Summer
# ...                 ...                             ...
# 757                  No                          Summer
# 489                 Yes                          Winter
# 1007                Yes                          Summer
# 327                  No                          Summer
# 145                  No                          Summer
#
#      Are you a business major?  ...  \
# 833                         No  ...
# 932                        Yes  ...
# 287                        Yes  ...
# 870                         No  ...
# 1025                        No  ...
# ...                        ...  ...
# 757                         No  ...
# 489                         No  ...
# 1007                        No  ...
# 327                         No  ...
# 145                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 833                                         Switzerland
# 932                                             germany
# 287                                                  UK
# 870                                               Italy
# 1025                                              China
# ...                                                 ...
# 757                                              Monaco
# 489                                               Swiss
# 1007                                            germany
# 327                                         South Korea
# 145                                           singapore
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 833                          Pink                               Reading
# 932                          blue                                 party
# 287                        purple              hanging out with friends
# 870                         Pink                        Watching movies
# 1025                         pink                              chatting
# ...                           ...                                   ...
# 757                          Blue                                  Golf
# 489                         black                                 Sleep
# 1007                       purple                              Relaxing
# 327                          Blue                         Watch YouTube
# 145                         green                                eating
#
#      What genre of music do you like the most?  \
# 833                                      R & B
# 932                                        pop
# 287                                        pop
# 870                                        Pop
# 1025                                      jazz
# ...                                        ...
# 757                                        Rap
# 489                                    Hip-hop
# 1007                                       rap
# 327                                        EDM
# 145                                        rnb
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 833                                                 Cat
# 932                                                 dog
# 287                                             Dolphin
# 870                                               Panda
# 1025                                                Cat
# ...                                                 ...
# 757                                                 Dog
# 489                                             Dog/Dog
# 1007                                              sloth
# 327                                                Lion
# 145                                               panda
#
#      What do you think is the hardest major at UIUC?  \
# 833                             Computer Engineering
# 932                                              ECE
# 287                                 computer science
# 870                                 Computer Science
# 1025                                              cs
# ...                                              ...
# 757                                 Computer Science
# 489                                               CS
# 1007                                Computer science
# 327                             Computer Engineering
# 145                                         comp sci
#
#      Who is your favorite music artist?  \
# 833                          The Weeknd
# 932                           pop smoke
# 287                               Drake
# 870                          The Weeknd
# 1025                       taylor swift
# ...                                 ...
# 757                               Drake
# 489                      Kendrick Lamar
# 1007                              Lucki
# 327                           Beethoven
# 145                          jhene aiko
#
#      What's your favorite social media app?  \
# 833                               Instagram
# 932                                    snap
# 287                                  Tiktok
# 870                                 Tik Tok
# 1025                                REDnote
# ...                                     ...
# 757                                  Tiktok
# 489                               Instagram
# 1007                              Instagram
# 327                                 YouTube
# 145                                  tiktok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 833                                          BrawlStars
# 932                                                 gta
# 287                                               Mario
# 870                                          Watermleon
# 1025                                  league of legends
# ...                                                 ...
# 757                                                2048
# 489                                   League of Legends
# 1007                                   Grand theft auto
# 327                                                Halo
# 145                                                 NaN
#
#      Where is your dream vacation spot?
# 833                              Hawaii
# 932                              hawaii
# 287                              Greece
# 870                              Italy
# 1025                            Orlando
# ...                                 ...
# 757                           Bora Bora
# 489                              Hawaii
# 1007                            bahamas
# 327                         South Korea
# 145                         south korea
#
# [535 rows x 150 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#             Name  Lab When flipping a coin, heads or tails?  \
# 984        jihan  Y07                                 Heads
# 393      Anishka  Y15                                 Heads
# 211         Mann  Y03                                 Tails
# 384         Alex  Y27                                 Heads
# 745       Chiara  Y06                                 Heads
# ...          ...  ...                                   ...
# 252        Yulin  Y32                                 Heads
# 881          Sam  Y21                                 Heads
# 1027      Andrew  Y35                                 Heads
# 1035       Janna  Y08                                 Heads
# 410   Keerthana   Y34                                 Heads
#
#      Is this your first year at UIUC?  \
# 984                    Not First Year
# 393                First Year at UIUC
# 211                First Year at UIUC
# 384                First Year at UIUC
# 745                First Year at UIUC
# ...                               ...
# 252                First Year at UIUC
# 881                First Year at UIUC
# 1027               First Year at UIUC
# 1035                   Not First Year
# 410                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 984                                           Chocolate
# 393                                             Vanilla
# 211                                             Vanilla
# 384                                           Chocolate
# 745                                             Vanilla
# ...                                                 ...
# 252                                           Chocolate
# 881                                             Vanilla
# 1027                                            Vanilla
# 1035                                            Vanilla
# 410                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 984                           Night                               Even
# 393                           Night                                Odd
# 211                         Morning                                Odd
# 384                         Morning                               Even
# 745                           Night                               Even
# ...                             ...                                ...
# 252                           Night                                Odd
# 881                           Night                                Odd
# 1027                          Night                               Even
# 1035                        Morning                               Even
# 410                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 984                 Yes                          Winter
# 393                 Yes                          Winter
# 211                  No                          Summer
# 384                  No                          Summer
# 745                 Yes                          Winter
# ...                 ...                             ...
# 252                 Yes                          Winter
# 881                 Yes                          Summer
# 1027                Yes                          Summer
# 1035                Yes                          Summer
# 410                  No                          Summer
#
#      Are you a business major?  ...  \
# 984                         No  ...
# 393                         No  ...
# 211                         No  ...
# 384                        Yes  ...
# 745                         No  ...
# ...                        ...  ...
# 252                         No  ...
# 881                         No  ...
# 1027                       Yes  ...
# 1035                        No  ...
# 410                        Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 984                                               japan
# 393                                             Finland
# 211                                               Italy
# 384                                               Italy
# 745                                              Italy
# ...                                                 ...
# 252                                               China
# 881                                              Norway
# 1027                                              China
# 1035                                            Germany
# 410                                             France
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 984                         white                                 phone
# 393                         Green               Talking with my friends
# 211                           Red              Hanging out with friends
# 384                          Pink                          Watch movies
# 745                         Blue               Hanging out with friends
# ...                           ...                                   ...
# 252                      Cerulean                           Watching TV
# 881                         Green                       Listen to music
# 1027                         blue                          With friends
# 1035                        Green                                  Yoga
# 410                         Green                       play badminton
#
#      What genre of music do you like the most?  \
# 984                                     hiphop
# 393                                    Hip hop
# 211                                        Rap
# 384                                       Rock
# 745                                House Music
# ...                                        ...
# 252                                      Indie
# 881                                Midwest Emo
# 1027                                     Indie
# 1035                                       EDM
# 410                                      R & B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 984                                                 dog
# 393                                               Panda
# 211                                                Lion
# 384                                                Lion
# 745                                               Tiger
# ...                                                 ...
# 252                                                 Cat
# 881                                             Panther
# 1027                                              Sloth
# 1035                                          House Cat
# 410                                              Koala
#
#      What do you think is the hardest major at UIUC?  \
# 984                                               cs
# 393                                 Computer Science
# 211                                 Computer Science
# 384                             Computer engineering
# 745                           Mechanical Engineering
# ...                                              ...
# 252                                              CSE
# 881                            Electical Engineering
# 1027                                     engineering
# 1035                                              CS
# 410                          Mechanical Engineering
#
#      Who is your favorite music artist?  \
# 984                               pgone
# 393                        Brent Faiyaz
# 211                        Travis Scott
# 384                           Bob Dylan
# 745                         John Summit
# ...                                 ...
# 252                     Phoebe Bridgers
# 881                Slaughter Beach, Dog
# 1027                           Bon Jovi
# 1035                               Rezz
# 410                         Kanye West
#
#      What's your favorite social media app?  \
# 984                                  tiktok
# 393                               Instagram
# 211                                  Tiktok
# 384                               Instagram
# 745                                 Tik Tok
# ...                                     ...
# 252                                 Twitter
# 881                                Snapchat
# 1027                               snapchat
# 1035                                   VSCO
# 410                                  TikTok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 984                                          video game
# 393                                                 NaN
# 211                                            Monopoly
# 384                                          Pickleball
# 745                                              Tennis
# ...                                                 ...
# 252                                     Animal Crossing
# 881                                           Minecraft
# 1027                                                2k
# 1035                            Ghosts in the graveyard
# 410                                       2048 Cupcakes
#
#      Where is your dream vacation spot?
# 984                               vegas
# 393                           Indonesia
# 211                               Italy
# 384                             Montana
# 745                   Montalcino Italy
# ...                                 ...
# 252                            Hokkaido
# 881                          Mount Fuji
# 1027                            iceland
# 1035                            Croatia
# 410                              Paris
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#           Name       Lab When flipping a coin, heads or tails?  \
# 3     TA Tyler       Y07                                 Tails
# 4       Sneha        Y17                                 Tails
# 5         Gage       Y10                                 Heads
# 7        Jaden       Y34                                 Heads
# 11       Najam       Y20                                 Tails
# ...        ...       ...                                   ...
# 1054  CA Maddy       Y36                                 Heads
# 1060  TA Jimmy       Y21                                 Tails
# 1062    Eunice       Y28                                 Heads
# 1066  CA Elise  Y11, Y33                                 Heads
# 1068     Bowen       Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 3                      Not First Year
# 4                  First Year at UIUC
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 11                 First Year at UIUC
# ...                               ...
# 1054                   Not First Year
# 1060               First Year at UIUC
# 1062               First Year at UIUC
# 1066                   Not First Year
# 1068               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 3                                             Chocolate
# 4                                               Vanilla
# 5                                               Vanilla
# 7                                             Chocolate
# 11                                            Chocolate
# ...                                                 ...
# 1054                                            Vanilla
# 1060                                          Chocolate
# 1062                                          Chocolate
# 1066                                            Vanilla
# 1068                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 3                             Night                               Even
# 4                             Night                               Even
# 5                             Night                               Even
# 7                           Morning                               Even
# 11                            Night                                Odd
# ...                             ...                                ...
# 1054                        Morning                               Even
# 1060                          Night                               Even
# 1062                          Night                               Even
# 1066                          Night                               Even
# 1068                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 3                    No                          Winter
# 4                    No                          Summer
# 5                   Yes                          Winter
# 7                    No                          Summer
# 11                   No                          Winter
# ...                 ...                             ...
# 1054                 No                          Summer
# 1060                 No                          Summer
# 1062                 No                          Summer
# 1066                Yes                          Summer
# 1068                 No                          Summer
#
#      Are you a business major?  ...  \
# 3                           No  ...
# 4                          Yes  ...
# 5                           No  ...
# 7                           No  ...
# 11                          No  ...
# ...                        ...  ...
# 1054                        No  ...
# 1060                        No  ...
# 1062                       Yes  ...
# 1066                        No  ...
# 1068                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 3                                                Canada
# 4                                                Canada
# 5                                               Canada
# 7                                                 japan
# 11                                             pakistan
# ...                                                 ...
# 1054                                             greece
# 1060                                                 UK
# 1062                                        south korea
# 1066                                            England
# 1068                                              China
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# 5                           Green                   Fishing or Hunting
# 7                            blue                     talk with friends
# 11                          Black                                 Chill
# ...                           ...                                   ...
# 1054                         pink                           working out
# 1060                        Black                        Watching shows
# 1062                         blue                         playing piano
# 1066                         Pink                          With friends
# 1068                       Purple                                 Films
#
#      What genre of music do you like the most?  \
# 3                                     Pop rock
# 4                                     Pop Rock
# 5                                 Grunge Rock
# 7                                          pop
# 11                                         rap
# ...                                        ...
# 1054                                       pop
# 1060                                       Pop
# 1062                                      kpop
# 1066                                 Indie pop
# 1068                                      Rocj
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 3                                                   Bee
# 4                                               Penguin
# 5                                                 Bear
# 7                                                   dog
# 11                                                horse
# ...                                                 ...
# 1054                                                cat
# 1060                                              Panda
# 1062                                              sloth
# 1066                                               Wolf
# 1068                                              Puppy
#
#      What do you think is the hardest major at UIUC?  \
# 3                               Chemical Engineering
# 4                                   Computer Science
# 5                                              Math
# 7                                                 CS
# 11                                         Chemistry
# ...                                              ...
# 1054                                        comp sci
# 1060                                         Physics
# 1062                                     engineering
# 1066                                            Eecs
# 1068                                     Engineering
#
#      Who is your favorite music artist?  \
# 3                            Billy Joel
# 4                       Imagine Dragons
# 5                            Jim Croce
# 7                                 keshi
# 11                           juice wrld
# ...                                 ...
# 1054                       taylor swift
# 1060                         Kanye West
# 1062                                IVE
# 1066                       Taylor swift
# 1068                         Kanye West
#
#      What's your favorite social media app?  \
# 3                                    Reddit
# 4                                 Instagram
# 5                                    Tiktok
# 7                                    wechat
# 11                                instagram
# ...                                     ...
# 1054                                 tiktok
# 1060                                Discord
# 1062                              instagram
# 1066                              Pinterest
# 1068                                    ins
#
#      What is your favorite game to play (either video game or IRL)?  \
# 3                                              Terraria
# 4                                            Beat Saber
# 5                                           Titanfall 2
# 7                                                   LOL
# 11                                    Football (soccer)
# ...                                                 ...
# 1054                                        super mario
# 1060                                              Poker
# 1062                                            genshin
# 1066                                           Pinochle
# 1068                                     Stardew Valley
#
#      Where is your dream vacation spot?
# 3                          My apartment
# 4                                 Italy
# 5                 Denali National Park
# 7                                 china
# 11                            mountains
# ...                                 ...
# 1054                             greece
# 1060                              Japan
# 1062                              Italy
# 1066                              Kenya
# 1068                              Tokyo
#
# [266 rows x 150 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# *(Since my code is only for the random selection of 50% people from the group, some people will be selected for twice)*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index) ]
control
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 8           Eman       Y11                                 Heads
# 12        Amanda       Y30                                 Heads
# 15        Roqaya       Y03                                 Heads
# 16       Aaliyay       Y30                                 Heads
# ...          ...       ...                                   ...
# 1059     CA Lara  Y19, Y20                                 Tails
# 1061   TA Kunlun  Y12, Y25                                 Heads
# 1063       Shlok       Y04                                 Heads
# 1065    Man Geun       Y04                                 Heads
# 1067     Chinmay       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 8                  First Year at UIUC
# 12                     Not First Year
# 15                 First Year at UIUC
# 16                 First Year at UIUC
# ...                               ...
# 1059                   Not First Year
# 1061               First Year at UIUC
# 1063               First Year at UIUC
# 1065                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 8                                             Chocolate
# 12                                              Vanilla
# 15                                            Chocolate
# 16                                              Vanilla
# ...                                                 ...
# 1059                                          Chocolate
# 1061                                          Chocolate
# 1063                                          Chocolate
# 1065                                            Vanilla
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 8                           Morning                               Even
# 12                            Night                               Even
# 15                          Morning                               Even
# 16                            Night                               Even
# ...                             ...                                ...
# 1059                          Night                               Even
# 1061                        Morning                               Even
# 1063                          Night                               Even
# 1065                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 8                    No                          Summer
# 12                  Yes                          Summer
# 15                   No                          Summer
# 16                  Yes                          Summer
# ...                 ...                             ...
# 1059                 No                          Summer
# 1061                Yes                          Summer
# 1063                 No                          Summer
# 1065                 No                          Winter
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 8                           No  ...
# 12                          No  ...
# 15                          No  ...
# 16                          No  ...
# ...                        ...  ...
# 1059                        No  ...
# 1061                        No  ...
# 1063                        No  ...
# 1065                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 8                                                   UAE
# 12                                                Italy
# 15                                                Qatar
# 16                                              Canada
# ...                                                 ...
# 1059                                             Canada
# 1061                                              China
# 1063                                             Monaco
# 1065                                              Korea
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 8                             Red                Hang out with friends
# 12                         Purple                              Sleeping
# 15                           pink                  hangout with friends
# 16                           blue                              on phone
# ...                           ...                                   ...
# 1059                        beige                               reading
# 1061                         blue                                  game
# 1063                        Black                    Listening to music
# 1065                         Blue                           Playstation
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 8                                          R&B
# 12                                 Alternative
# 15                                         pop
# 16                                         rnb
# ...                                        ...
# 1059                                Riot grrrl
# 1061                                      jazz
# 1063                                   Hip Hop
# 1065                                       Pop
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 8                                               Unicorn
# 12                                                Bunny
# 15                                                sloth
# 16                                                 bird
# ...                                                 ...
# 1059                                        sea anemone
# 1061                                               egal
# 1063                                                Dog
# 1065                                                Dog
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 8                                            Physics
# 12                              Computer Engineering
# 15                                  computer science
# 16                             aerospace engineering
# ...                                              ...
# 1059                                         Physics
# 1061                                              cs
# 1063                            Computer Engineering
# 1065                                              CS
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 8                                   SZA
# 12                               Hozier
# 15                         Dominic fike
# 16                          Frank Ocean
# ...                                 ...
# 1059                            Slant 6
# 1061                           Coldplay
# 1063                         Kanye West
# 1065                                 IU
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 8                                 Instagram
# 12                                  Twitter
# 15                                instagram
# 16                                   tiktok
# ...                                     ...
# 1059                                 Reddit
# 1061                                 Wechat
# 1063                              Instagram
# 1065                              Instagram
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 8                                                  Sims
# 12                                       Stardew Valley
# 15                                             monopoly
# 16                                               sims 4
# ...                                                 ...
# 1059                                           Oxenfree
# 1061                                          overwatch
# 1063                                              Chess
# 1065                                              NBA2k
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 8                               Greece
# 12                               Japan
# 15                             Maldives
# 16                               eurpoe
# ...                                 ...
# 1059                              Japan
# 1061                                 CA
# 1063                              Spain
# 1065                             Cancun
# 1067                             Monaco
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you?
# - If you did not fill out the "Hello Survey", then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead  *(those are the names we used in the `Name` column).*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
# ...feel free to add extra "Code" cells here if needed.
fm = treatment[treatment.Name == 'Beichen']
fm
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 829  Beichen  Y12                                 Heads
#
#     Is this your first year at UIUC?  \
# 829               First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 829                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 829                        Morning                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 829                 No                          Summer
#
#     Are you a business major?  ...  \
# 829                        No  ...
#
#     Besides the US, what country would you like to live in?  \
# 829                                     China, England
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 829                         Buke                               running
#
#     What genre of music do you like the most?  \
# 829                                 Classical
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 829                                                cat
#
#     What do you think is the hardest major at UIUC?  \
# 829                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 829                      Yonezu Kenshi                                    INS
#
#     What is your favorite game to play (either video game or IRL)?  \
# 829                                               FIFA
#
#     Where is your dream vacation spot?
# 829                             Franch
#
# [1 rows x 150 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q5: Which group where you in -- treatment or control?**

# %% [markdown]
# *(Treatment)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac = 0.5)
df1_treatment
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 1034       Eman       Y21                                 Tails
# 895        Drew       Y07                                 Tails
# 601       Kevin       Y20                                 Heads
# 423        Eric       Y02                                 Heads
# 1061  TA Kunlun  Y12, Y25                                 Heads
# ...         ...       ...                                   ...
# 578    Sathvik        Y03                                 Tails
# 752       Abhay       Y31                                 Heads
# 675        Josh       Y34                                 Tails
# 841         liv       Y18                                 Heads
# 110        Ryan       Y12                                 Tails
#
#      Is this your first year at UIUC?  \
# 1034                   Not First Year
# 895                First Year at UIUC
# 601                First Year at UIUC
# 423                    Not First Year
# 1061               First Year at UIUC
# ...                               ...
# 578                    Not First Year
# 752                First Year at UIUC
# 675                First Year at UIUC
# 841                First Year at UIUC
# 110                    Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1034                                            Vanilla
# 895                                             Vanilla
# 601                                           Chocolate
# 423                                           Chocolate
# 1061                                          Chocolate
# ...                                                 ...
# 578                                             Vanilla
# 752                                           Chocolate
# 675                                           Chocolate
# 841                                             Vanilla
# 110                                             Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1034                          Night                                Odd
# 895                           Night                               Even
# 601                         Morning                               Even
# 423                         Morning                               Even
# 1061                        Morning                               Even
# ...                             ...                                ...
# 578                         Morning                               Even
# 752                           Night                               Even
# 675                         Morning                               Even
# 841                           Night                               Even
# 110                         Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1034                Yes                          Summer
# 895                 Yes                          Summer
# 601                 Yes                          Winter
# 423                  No                          Winter
# 1061                Yes                          Summer
# ...                 ...                             ...
# 578                  No                          Summer
# 752                 Yes                          Summer
# 675                 Yes                          Summer
# 841                 Yes                          Summer
# 110                 Yes                          Summer
#
#      Are you a business major?  ...  \
# 1034                        No  ...
# 895                         No  ...
# 601                        Yes  ...
# 423                         No  ...
# 1061                        No  ...
# ...                        ...  ...
# 578                        Yes  ...
# 752                         No  ...
# 675                        Yes  ...
# 841                        NaN  ...
# 110                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 1034                                           Tropical
# 895                                     Greece or Japan
# 601                                               China
# 423                                               Spain
# 1061                                              China
# ...                                                 ...
# 578                                     Middle eastern
# 752                                               India
# 675                                       Saudi Arabia
# 841                                              france
# 110                                              Canada
#
#      What is your favorite color?  \
# 1034                        Black
# 895                          Blue
# 601                          Gray
# 423                          Blue
# 1061                         blue
# ...                           ...
# 578                         blue
# 752                          Blue
# 675                         black
# 841                          blue
# 110                         Green
#
#                 Favorite way to spend your free time?  \
# 1034                                             live
# 895   Playing basketball or hanging out with friends.
# 601                                             Chill
# 423                                  Drink w/ friends
# 1061                                             game
# ...                                               ...
# 578                               playing basketball
# 752                                   Watching movies
# 675                                       working out
# 841                                      with friends
# 110                                With my girlfriend
#
#      What genre of music do you like the most?  \
# 1034                                       NaN
# 895                               Folk/Country
# 601                                        Rap
# 423                                     HipHop
# 1061                                      jazz
# ...                                        ...
# 578                                        rap
# 752                                       Rock
# 675                                    Hip Hop
# 841                                    country
# 110                                 Indie Rock
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1034                                               LIon
# 895                                               Eagle
# 601                                               Wolf
# 423                                                Lion
# 1061                                               egal
# ...                                                 ...
# 578                                               tiger
# 752                                                orca
# 675                                           butterfly
# 841                                                 dog
# 110                                            Elephant
#
#      What do you think is the hardest major at UIUC?  \
# 1034                                      Eng/Compsi
# 895                                 Computer Science
# 601                                               CS
# 423                                      Mathematics
# 1061                                              cs
# ...                                              ...
# 578                            computer engineering
# 752                                          Physics
# 675                                               CS
# 841                                      engineering
# 110                             Computer Engineering
#
#      Who is your favorite music artist?  \
# 1034                                NaN
# 895                     Don't have one.
# 601                          Kanye West
# 423                               Colde
# 1061                           Coldplay
# ...                                 ...
# 578                               Gunna
# 752                        Fall Out Boy
# 675                                  NF
# 841                          luke combs
# 110                         Mac Demarco
#
#      What's your favorite social media app?  \
# 1034                                  Insta
# 895                                Snapchat
# 601                                     NaN
# 423                               instagram
# 1061                                 Wechat
# ...                                     ...
# 578                                  tiktok
# 752                                   Qoura
# 675                                Snapchat
# 841                                snapchat
# 110                                LinkedIn
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1034                                             Roblox
# 895                                            NBA 2k25
# 601                                                 NaN
# 423                                          video game
# 1061                                          overwatch
# ...                                                 ...
# 578                                          basketball
# 752                                        Apex Legends
# 675                                           Spikeball
# 841                                          pickleball
# 110                                          Pickleball
#
#      Where is your dream vacation spot?
# 1034                           tropical
# 895                       Greek Islands
# 601                               Paris
# 423                              Hawaii
# 1061                                 CA
# ...                                 ...
# 578                          Bora Bora
# 752                              Venice
# 675                             The Gym
# 841                                fiji
# 110                     Washington D.C.
#
# [126 rows x 150 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 7        Jaden  Y34                                 Heads
# 11       Najam  Y20                                 Tails
# 19       Brady  Y16                                 Heads
# 22        Yash  Y25                                 Heads
# 50       Jonah  Y27                                 Heads
# ...        ...  ...                                   ...
# 993   Emiliano  Y21                                 Heads
# 996       Josh  Y35                                 Heads
# 1039     Vedik  Y22                                 Heads
# 1046     harry  Y99                                 Heads
# 1065  Man Geun  Y04                                 Heads
#
#      Is this your first year at UIUC?  \
# 7                  First Year at UIUC
# 11                 First Year at UIUC
# 19                 First Year at UIUC
# 22                 First Year at UIUC
# 50                 First Year at UIUC
# ...                               ...
# 993                    Not First Year
# 996                    Not First Year
# 1039               First Year at UIUC
# 1046                   Not First Year
# 1065                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 7                                             Chocolate
# 11                                            Chocolate
# 19                                              Vanilla
# 22                                                  NaN
# 50                                              Vanilla
# ...                                                 ...
# 993                                             Vanilla
# 996                                             Vanilla
# 1039                                          Chocolate
# 1046                                          Chocolate
# 1065                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 7                           Morning                               Even
# 11                            Night                                Odd
# 19                          Morning                                Odd
# 22                          Morning                                Odd
# 50                            Night                               Even
# ...                             ...                                ...
# 993                           Night                               Even
# 996                         Morning                               Even
# 1039                          Night                               Even
# 1046                        Morning                               Even
# 1065                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 7                    No                          Summer
# 11                   No                          Winter
# 19                   No                          Summer
# 22                  Yes                          Winter
# 50                  Yes                          Summer
# ...                 ...                             ...
# 993                 Yes                          Summer
# 996                 Yes                          Summer
# 1039                 No                          Summer
# 1046                Yes                          Summer
# 1065                 No                          Winter
#
#      Are you a business major?  ...  \
# 7                           No  ...
# 11                          No  ...
# 19                         Yes  ...
# 22                         Yes  ...
# 50                          No  ...
# ...                        ...  ...
# 993                         No  ...
# 996                         No  ...
# 1039                        No  ...
# 1046                       Yes  ...
# 1065                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 7                                                 japan
# 11                                             pakistan
# 19                                                Italy
# 22                                                India
# 50                                                Italy
# ...                                                 ...
# 993                                    Mexico or Europe
# 996                                               Italy
# 1039                                                 UK
# 1046                                              china
# 1065                                              Korea
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 7                            blue                     talk with friends
# 11                          Black                                 Chill
# 19                           Blue                               Golfing
# 22                           blue                       Watching movies
# 50                          Green                         Playing chess
# ...                           ...                                   ...
# 993                          Blue                      Watching movies
# 996                        Orange                                 Sleep
# 1039                         Blue     With my roomate watching beyblade
# 1046                          red                                 games
# 1065                         Blue                           Playstation
#
#      What genre of music do you like the most?  \
# 7                                          pop
# 11                                         rap
# 19                                     Country
# 22                                 Punjabi rap
# 50                                Classic rock
# ...                                        ...
# 993                         Corridos tumbados
# 996                                    Country
# 1039                                       Rap
# 1046                                    hiphop
# 1065                                       Pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 7                                                   dog
# 11                                                horse
# 19                                                 Lion
# 22                                                 lion
# 50                                                  Dog
# ...                                                 ...
# 993                                          Fish. Puma
# 996                                               Zebra
# 1039                                     Siberian Husky
# 1046                                               lion
# 1065                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 7                                                 CS
# 11                                         Chemistry
# 19                                  Computer Science
# 22                                           physics
# 50                                  Computer science
# ...                                              ...
# 993                                             BIOE
# 996                                      Engineering
# 1039                                      CS+Physics
# 1046                                            chem
# 1065                                              CS
#
#      Who is your favorite music artist?  \
# 7                                 keshi
# 11                           juice wrld
# 19                           Zach Bryan
# 22                        playboi carti
# 50                      Michael Jackson
# ...                                 ...
# 993                          Kanye West
# 996                       Morgan Wallen
# 1039                               Dave
# 1046                             taylor
# 1065                                 IU
#
#      What's your favorite social media app?  \
# 7                                    wechat
# 11                                instagram
# 19                                 Snapchat
# 22                                instagram
# 50                                  Discord
# ...                                     ...
# 993                                 youtube
# 996                               Instagram
# 1039                                  Insta
# 1046                                  music
# 1065                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 7                                                   LOL
# 11                                    Football (soccer)
# 19                                    Pickup Basketball
# 22                         Star Wars Jedi: Fallen Order
# 50                                                Chess
# ...                                                 ...
# 993                                               Ea24
# 996                                          Volleyball
# 1039                                          Minecraft
# 1046                                                lol
# 1065                                              NBA2k
#
#      Where is your dream vacation spot?
# 7                                 china
# 11                            mountains
# 19                                 Rome
# 22                             Maldives
# 50                               Venice
# ...                                 ...
# 993                              Norway
# 996                               Italy
# 1039                        Switzerland
# 1046                               home
# 1065                             Cancun
#
# [126 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#             Name  Lab When flipping a coin, heads or tails?  \
# 417        Sarah  Y16                                 Heads
# 703       Summer  Y17                                 Tails
# 239       Elina   Y16                                 Heads
# 788      Charlie  Y26                                 Tails
# 729       Sydney  Y24                                 Tails
# ...          ...  ...                                   ...
# 751       Maansi  Y99                                 Heads
# 426      William  Y34                                 Heads
# 1021        Abby  Y33                                 Tails
# 832     Nicholas  Y19                                 Heads
# 251   Taranpreet  Y33                                 Heads
#
#      Is this your first year at UIUC?  \
# 417                    Not First Year
# 703                First Year at UIUC
# 239                First Year at UIUC
# 788                First Year at UIUC
# 729                First Year at UIUC
# ...                               ...
# 751                First Year at UIUC
# 426                First Year at UIUC
# 1021               First Year at UIUC
# 832                    Not First Year
# 251                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 417                                           Chocolate
# 703                                           Chocolate
# 239                                           Chocolate
# 788                                           Chocolate
# 729                                             Vanilla
# ...                                                 ...
# 751                                           Chocolate
# 426                                           Chocolate
# 1021                                          Chocolate
# 832                                             Vanilla
# 251                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 417                         Morning                               Even
# 703                           Night                               Even
# 239                           Night                               Even
# 788                         Morning                                Odd
# 729                         Morning                               Even
# ...                             ...                                ...
# 751                           Night                               Even
# 426                           Night                                Odd
# 1021                          Night                                Odd
# 832                           Night                               Even
# 251                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 417                 Yes                          Summer
# 703                 Yes                          Summer
# 239                 Yes                          Winter
# 788                 Yes                          Summer
# 729                 Yes                          Summer
# ...                 ...                             ...
# 751                 Yes                          Summer
# 426                  No                          Summer
# 1021                Yes                          Winter
# 832                  No                          Winter
# 251                 Yes                          Winter
#
#      Are you a business major?  ...  \
# 417                         No  ...
# 703                         No  ...
# 239                         No  ...
# 788                        Yes  ...
# 729                        Yes  ...
# ...                        ...  ...
# 751                         No  ...
# 426                         No  ...
# 1021                        No  ...
# 832                         No  ...
# 251                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 417                                             Sweden
# 703                                               Spain
# 239                                               korea
# 788                                         New Zealand
# 729                                               Italy
# ...                                                 ...
# 751                                         New Zealand
# 426                                              Uganda
# 1021                                            Ireland
# 832                                              Greece
# 251                                             Germany
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 417                          blue                               cooking
# 703                        Orange                               Reading
# 239                          blue                                  game
# 788                          Blue                Go on a walk in nature
# 729                          pink              Hanging out with friends
# ...                           ...                                   ...
# 751                        Purple                      Watching movies
# 426                        Purple                                 Sleep
# 1021                          Red           Eating and watching YouTube
# 832                          Blue                                 Sleep
# 251                         green                               Reading
#
#      What genre of music do you like the most?  \
# 417                                        Pop
# 703                                        pop
# 239                                       kpop
# 788                                        Pop
# 729                                    Country
# ...                                        ...
# 751                                Hip Hop/RnB
# 426                                        Rap
# 1021                                       Pop
# 832                               hip-hop/ R&B
# 251                                   Old Rock
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 417                                                 Cat
# 703                                            elephant
# 239                                                 dog
# 788                                                 Owl
# 729                                               koala
# ...                                                 ...
# 751                                               Puppy
# 426                                              lebron
# 1021                                                Cat
# 832                                              A bird
# 251                                                Lion
#
#      What do you think is the hardest major at UIUC?  \
# 417                                Computer Science
# 703                                   Bioengineering
# 239                                               cs
# 788                             Computer Engineering
# 729                                      Engineering
# ...                                              ...
# 751                                               CS
# 426                                             Math
# 1021                              Aerospace Engineer
# 832                            Eletrical Engineering
# 251                                       Philosophy
#
#      Who is your favorite music artist?  \
# 417                             Li Chen
# 703                        Taylor Swift
# 239                           seventeen
# 788                               Drake
# 729                          Zach Bryan
# ...                                 ...
# 751                             Kehlani
# 426                                 KUN
# 1021                       Frank Ocean
# 832                         Kenny Mason
# 251                               Queen
#
#      What's your favorite social media app?  \
# 417                                  Wechat
# 703                                  TikTok
# 239                               instagram
# 788                                 Youtube
# 729                                 Tik tok
# ...                                     ...
# 751                               Instagram
# 426                                     Ins
# 1021                              Instagram
# 832                               Instagram
# 251                                Whatsapp
#
#      What is your favorite game to play (either video game or IRL)?  \
# 417                                       mine clearing
# 703                                   Super Mario Bros.
# 239                                   league of legends
# 788                                            Baseball
# 729                                         Connections
# ...                                                 ...
# 751                                                Clue
# 426                                            NBA Live
# 1021                                           Monopoly
# 832                                              Skyrim
# 251                                     Devil May Cry 5
#
#      Where is your dream vacation spot?
# 417                              Hainan
# 703                               Japan
# 239                              hawaii
# 788                             Namibia
# 729                             Bahamas
# ...                                 ...
# 751                             Iceland
# 426                           Greenland
# 1021                            Ireland
# 832                              Brazil
# 251                              Sicily
#
# [408 rows x 150 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 2       Angelina       Y13                                 Tails
# 3       TA Tyler       Y07                                 Tails
# 4         Sneha        Y17                                 Tails
# 6          Mark        Y04                                 Heads
# ...          ...       ...                                   ...
# 1063       Shlok       Y04                                 Heads
# 1064      Wesley       Y02                                 Tails
# 1066    CA Elise  Y11, Y33                                 Heads
# 1067     Chinmay       Y11                                 Heads
# 1069    kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 4                  First Year at UIUC
# 6                      Not First Year
# ...                               ...
# 1063               First Year at UIUC
# 1064                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 4                                               Vanilla
# 6                                             Chocolate
# ...                                                 ...
# 1063                                          Chocolate
# 1064                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 4                             Night                               Even
# 6                           Morning                               Even
# ...                             ...                                ...
# 1063                          Night                               Even
# 1064                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 4                    No                          Summer
# 6                    No                          Winter
# ...                 ...                             ...
# 1063                 No                          Summer
# 1064                 No                          Summer
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                          Yes  ...
# 6                           No  ...
# ...                        ...  ...
# 1063                        No  ...
# 1064                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 4                                                Canada
# 6                                                Sweden
# ...                                                 ...
# 1063                                             Monaco
# 1064                                              japan
# 1066                                            England
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# 6                           green                               reading
# ...                           ...                                   ...
# 1063                        Black                    Listening to music
# 1064                         blue                                 sleep
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 4                                     Pop Rock
# 6                                          pop
# ...                                        ...
# 1063                                   Hip Hop
# 1064                                       pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 4                                               Penguin
# 6                                                 Zebra
# ...                                                 ...
# 1063                                                Dog
# 1064                                         dog/ camel
# 1066                                               Wolf
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 4                                   Computer Science
# 6                               computer engineering
# ...                                              ...
# 1063                            Computer Engineering
# 1064                                         english
# 1066                                            Eecs
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 4                       Imagine Dragons
# 6                                   sza
# ...                                 ...
# 1063                         Kanye West
# 1064                         juice wrld
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 4                                 Instagram
# 6                                 instagram
# ...                                     ...
# 1063                              Instagram
# 1064                                youtube
# 1066                              Pinterest
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 4                                            Beat Saber
# 6                                              Fortnite
# ...                                                 ...
# 1063                                              Chess
# 1064                                        brawl stars
# 1066                                           Pinochle
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 4                                 Italy
# 6                             australia
# ...                                 ...
# 1063                              Spain
# 1064                              japan
# 1066                              Kenya
# 1067                             Monaco
# 1069                            iceland
#
# [407 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment,df2_treatment])
treatment
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1034        Eman       Y21                                 Tails
# 895         Drew       Y07                                 Tails
# 601        Kevin       Y20                                 Heads
# 423         Eric       Y02                                 Heads
# 1061   TA Kunlun  Y12, Y25                                 Heads
# ...          ...       ...                                   ...
# 751       Maansi       Y99                                 Heads
# 426      William       Y34                                 Heads
# 1021        Abby       Y33                                 Tails
# 832     Nicholas       Y19                                 Heads
# 251   Taranpreet       Y33                                 Heads
#
#      Is this your first year at UIUC?  \
# 1034                   Not First Year
# 895                First Year at UIUC
# 601                First Year at UIUC
# 423                    Not First Year
# 1061               First Year at UIUC
# ...                               ...
# 751                First Year at UIUC
# 426                First Year at UIUC
# 1021               First Year at UIUC
# 832                    Not First Year
# 251                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1034                                            Vanilla
# 895                                             Vanilla
# 601                                           Chocolate
# 423                                           Chocolate
# 1061                                          Chocolate
# ...                                                 ...
# 751                                           Chocolate
# 426                                           Chocolate
# 1021                                          Chocolate
# 832                                             Vanilla
# 251                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1034                          Night                                Odd
# 895                           Night                               Even
# 601                         Morning                               Even
# 423                         Morning                               Even
# 1061                        Morning                               Even
# ...                             ...                                ...
# 751                           Night                               Even
# 426                           Night                                Odd
# 1021                          Night                                Odd
# 832                           Night                               Even
# 251                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1034                Yes                          Summer
# 895                 Yes                          Summer
# 601                 Yes                          Winter
# 423                  No                          Winter
# 1061                Yes                          Summer
# ...                 ...                             ...
# 751                 Yes                          Summer
# 426                  No                          Summer
# 1021                Yes                          Winter
# 832                  No                          Winter
# 251                 Yes                          Winter
#
#      Are you a business major?  ...  \
# 1034                        No  ...
# 895                         No  ...
# 601                        Yes  ...
# 423                         No  ...
# 1061                        No  ...
# ...                        ...  ...
# 751                         No  ...
# 426                         No  ...
# 1021                        No  ...
# 832                         No  ...
# 251                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 1034                                           Tropical
# 895                                     Greece or Japan
# 601                                               China
# 423                                               Spain
# 1061                                              China
# ...                                                 ...
# 751                                         New Zealand
# 426                                              Uganda
# 1021                                            Ireland
# 832                                              Greece
# 251                                             Germany
#
#      What is your favorite color?  \
# 1034                        Black
# 895                          Blue
# 601                          Gray
# 423                          Blue
# 1061                         blue
# ...                           ...
# 751                        Purple
# 426                        Purple
# 1021                          Red
# 832                          Blue
# 251                         green
#
#                 Favorite way to spend your free time?  \
# 1034                                             live
# 895   Playing basketball or hanging out with friends.
# 601                                             Chill
# 423                                  Drink w/ friends
# 1061                                             game
# ...                                               ...
# 751                                  Watching movies
# 426                                             Sleep
# 1021                      Eating and watching YouTube
# 832                                             Sleep
# 251                                           Reading
#
#      What genre of music do you like the most?  \
# 1034                                       NaN
# 895                               Folk/Country
# 601                                        Rap
# 423                                     HipHop
# 1061                                      jazz
# ...                                        ...
# 751                                Hip Hop/RnB
# 426                                        Rap
# 1021                                       Pop
# 832                               hip-hop/ R&B
# 251                                   Old Rock
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1034                                               LIon
# 895                                               Eagle
# 601                                               Wolf
# 423                                                Lion
# 1061                                               egal
# ...                                                 ...
# 751                                               Puppy
# 426                                              lebron
# 1021                                                Cat
# 832                                              A bird
# 251                                                Lion
#
#      What do you think is the hardest major at UIUC?  \
# 1034                                      Eng/Compsi
# 895                                 Computer Science
# 601                                               CS
# 423                                      Mathematics
# 1061                                              cs
# ...                                              ...
# 751                                               CS
# 426                                             Math
# 1021                              Aerospace Engineer
# 832                            Eletrical Engineering
# 251                                       Philosophy
#
#      Who is your favorite music artist?  \
# 1034                                NaN
# 895                     Don't have one.
# 601                          Kanye West
# 423                               Colde
# 1061                           Coldplay
# ...                                 ...
# 751                             Kehlani
# 426                                 KUN
# 1021                       Frank Ocean
# 832                         Kenny Mason
# 251                               Queen
#
#      What's your favorite social media app?  \
# 1034                                  Insta
# 895                                Snapchat
# 601                                     NaN
# 423                               instagram
# 1061                                 Wechat
# ...                                     ...
# 751                               Instagram
# 426                                     Ins
# 1021                              Instagram
# 832                               Instagram
# 251                                Whatsapp
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1034                                             Roblox
# 895                                            NBA 2k25
# 601                                                 NaN
# 423                                          video game
# 1061                                          overwatch
# ...                                                 ...
# 751                                                Clue
# 426                                            NBA Live
# 1021                                           Monopoly
# 832                                              Skyrim
# 251                                     Devil May Cry 5
#
#      Where is your dream vacation spot?
# 1034                           tropical
# 895                       Greek Islands
# 601                               Paris
# 423                              Hawaii
# 1061                                 CA
# ...                                 ...
# 751                             Iceland
# 426                           Greenland
# 1021                            Ireland
# 832                              Brazil
# 251                              Sicily
#
# [534 rows x 150 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control,df2_control])
control
# Out:
#           Name       Lab When flipping a coin, heads or tails?  \
# 7        Jaden       Y34                                 Heads
# 11       Najam       Y20                                 Tails
# 19       Brady       Y16                                 Heads
# 22        Yash       Y25                                 Heads
# 50       Jonah       Y27                                 Heads
# ...        ...       ...                                   ...
# 1063     Shlok       Y04                                 Heads
# 1064    Wesley       Y02                                 Tails
# 1066  CA Elise  Y11, Y33                                 Heads
# 1067   Chinmay       Y11                                 Heads
# 1069  kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 7                  First Year at UIUC
# 11                 First Year at UIUC
# 19                 First Year at UIUC
# 22                 First Year at UIUC
# 50                 First Year at UIUC
# ...                               ...
# 1063               First Year at UIUC
# 1064                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 7                                             Chocolate
# 11                                            Chocolate
# 19                                              Vanilla
# 22                                                  NaN
# 50                                              Vanilla
# ...                                                 ...
# 1063                                          Chocolate
# 1064                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 7                           Morning                               Even
# 11                            Night                                Odd
# 19                          Morning                                Odd
# 22                          Morning                                Odd
# 50                            Night                               Even
# ...                             ...                                ...
# 1063                          Night                               Even
# 1064                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 7                    No                          Summer
# 11                   No                          Winter
# 19                   No                          Summer
# 22                  Yes                          Winter
# 50                  Yes                          Summer
# ...                 ...                             ...
# 1063                 No                          Summer
# 1064                 No                          Summer
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 7                           No  ...
# 11                          No  ...
# 19                         Yes  ...
# 22                         Yes  ...
# 50                          No  ...
# ...                        ...  ...
# 1063                        No  ...
# 1064                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 7                                                 japan
# 11                                             pakistan
# 19                                                Italy
# 22                                                India
# 50                                                Italy
# ...                                                 ...
# 1063                                             Monaco
# 1064                                              japan
# 1066                                            England
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 7                            blue                     talk with friends
# 11                          Black                                 Chill
# 19                           Blue                               Golfing
# 22                           blue                       Watching movies
# 50                          Green                         Playing chess
# ...                           ...                                   ...
# 1063                        Black                    Listening to music
# 1064                         blue                                 sleep
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 7                                          pop
# 11                                         rap
# 19                                     Country
# 22                                 Punjabi rap
# 50                                Classic rock
# ...                                        ...
# 1063                                   Hip Hop
# 1064                                       pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 7                                                   dog
# 11                                                horse
# 19                                                 Lion
# 22                                                 lion
# 50                                                  Dog
# ...                                                 ...
# 1063                                                Dog
# 1064                                         dog/ camel
# 1066                                               Wolf
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 7                                                 CS
# 11                                         Chemistry
# 19                                  Computer Science
# 22                                           physics
# 50                                  Computer science
# ...                                              ...
# 1063                            Computer Engineering
# 1064                                         english
# 1066                                            Eecs
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 7                                 keshi
# 11                           juice wrld
# 19                           Zach Bryan
# 22                        playboi carti
# 50                      Michael Jackson
# ...                                 ...
# 1063                         Kanye West
# 1064                         juice wrld
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 7                                    wechat
# 11                                instagram
# 19                                 Snapchat
# 22                                instagram
# 50                                  Discord
# ...                                     ...
# 1063                              Instagram
# 1064                                youtube
# 1066                              Pinterest
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 7                                                   LOL
# 11                                    Football (soccer)
# 19                                    Pickup Basketball
# 22                         Star Wars Jedi: Fallen Order
# 50                                                Chess
# ...                                                 ...
# 1063                                              Chess
# 1064                                        brawl stars
# 1066                                           Pinochle
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 7                                 china
# 11                            mountains
# 19                                 Rome
# 22                             Maldives
# 50                               Venice
# ...                                 ...
# 1063                              Spain
# 1064                              japan
# 1066                              Kenya
# 1067                             Monaco
# 1069                            iceland
#
# [533 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or 
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
